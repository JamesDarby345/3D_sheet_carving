# %%
import nrrd
import numpy as np
import os
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider
from skimage.segmentation import mark_boundaries
import cv2
from scipy import ndimage as ndi
from helper import *
import graph_tool.all as gt
import plotly.graph_objects as go
import time

current_directory = os.getcwd()
label_path = f"{current_directory}/data/label/manual_1_label.nrrd"
raw_data_path = f"{current_directory}/data/raw/manual_1_raw.nrrd"

mask_data, mask_header = nrrd.read(label_path)
raw_data, raw_header = nrrd.read(raw_data_path)

# %%
#create reduced data

reduction_factor = 2
reduced_mask_data = reduce_array(mask_data, (reduction_factor,reduction_factor,reduction_factor), method='mean')
reduced_raw_data = reduce_array(raw_data, (reduction_factor,reduction_factor,reduction_factor), method='mean')
print(mask_data.shape, reduced_mask_data.shape)
# Out:
# (256, 256, 256) (128, 128, 128)

# %%
#create origianl and rotated graphs

# original_directed_graph, wp = create_directed_energy_graph_from_mask(reduced_mask_data)
# original_directed_graph, original_source, original_sink, original_weights = add_directed_source_sink(original_directed_graph, reduced_mask_data.shape[0], reduced_mask_data.shape[1], reduced_mask_data.shape[2])
# o_src, o_tgt = original_directed_graph.vertex(original_source), original_directed_graph.vertex(original_sink)

axis = 1 #0 for x, 1 for y and 2 for z
k = 1 # number of times to rotate the array
# due to the direction and symmetry, only a single rotation 
# on y and z along with the original is needed to get the best cut
reduced_mask_data_t = np.rot90(reduced_mask_data, k=k,  axes=(axis, (axis+1)%3))
reduced_raw_data_t = np.rot90(reduced_raw_data, k=k, axes=(axis, (axis+1)%3))

rotated_directed_graph, wp = create_directed_energy_graph_from_mask(reduced_mask_data_t)
rotated_directed_graph, rotated_source, rotated_sink, rotated_weights = add_directed_source_sink(rotated_directed_graph, reduced_mask_data_t.shape[0], reduced_mask_data_t.shape[1], reduced_mask_data_t.shape[2])
r_src, r_tgt = rotated_directed_graph.vertex(rotated_source), rotated_directed_graph.vertex(rotated_sink)
# Out:
# 128 128 128

# %%
def calculate_seam_iter(directed_graph, src, tgt, weights, test_size):
    # Compute the residual capactiy of the edges
    # stime = time.time()
    # res = gt.boykov_kolmogorov_max_flow(directed_graph, src, tgt, weights) #time complexity: edges * vertices^2 * abs(min cut) 
    # print("Time taken to calculate max flow boykov:", time.time()-stime)
    sptime = time.time()
    res = gt.push_relabel_max_flow(directed_graph, src, tgt, weights) #time complexity: vertices^3 <- scales better for our graph
    print("Time taken to calculate max flow push relabel:", time.time()-sptime)
    stime = time.time()
    #use the residual graph to get the max flow
    flow = sum(weights[e] - res[e] for e in tgt.in_edges())
    # print("The maximum flow from source to sink is:", flow)
    print("Time taken to calculate max flow:", time.time()-stime, "flow:", flow)
    stime = time.time()
    # Determine the minimum cut partition
    part = gt.min_st_cut(directed_graph, src, weights, res)
    # print("The number of vertices in the partiton:", sum(part))
    print("Time taken to calculate max flow and min cut:", time.time()-stime)
    # Find the boundary vertices
    stime = time.time()
    boundary_vertices = find_boundary_vertices(np.array(directed_graph.get_edges()), part)
    # print("Number of boundary vertices:", len(boundary_vertices))
    print("Time taken to calculate seam:", time.time()-stime)

    shape = (test_size, test_size, test_size)

    # Convert the boundary vertices to a 3D array
    stime = time.time()
    boundary_array = boundary_vertices_to_array(boundary_vertices, shape, 'x')
    # print("Boundary points marked:", np.sum(boundary_array))
    print("Time taken to convert boundary vertices to array:", time.time()-stime)

    stime = time.time()
    graph_seam_indices = seam_voxels_to_graph_indices(boundary_array)
    # print("Number of graph indices in the seam:", len(graph_seam_indices))
    print("Time taken to convert seam voxels to graph indices:", time.time()-stime)
    swtime = time.time()
    weights = update_outgoing_edges_p(directed_graph, graph_seam_indices, 1e8) #this is a bottleneck
    print("Time taken to update weights outside fxn:", time.time()-swtime)

    return boundary_array, weights, flow

# %%
original_boundary_array = np.zeros(reduced_mask_data.shape)
rotated_boundary_array = np.zeros(reduced_mask_data_t.shape)

# %%
iters = 32
for i in range(0,iters):
    # bau, original_weights = calculate_seam_iter(original_directed_graph, o_src, o_tgt, original_weights, reduced_mask_data.shape[0])
    rbau, rotated_weights, flow = calculate_seam_iter(rotated_directed_graph, r_src, r_tgt, rotated_weights, reduced_mask_data_t.shape[0])

    # original_boundary_array += bau

    overlap = np.sum(np.logical_and(rotated_boundary_array, rbau))
    print("Sum of overlap:", overlap)
    rotated_boundary_array += rbau

    print("Iteration:", i)
# Out:
# Time taken to calculate max flow push relabel: 22.853574991226196
# Time taken to calculate max flow: 0.1616818904876709 flow: 24331
# Time taken to calculate max flow and min cut: 0.8152980804443359
# edges that cross the partition: 12452352
# boundary vertices: 27181
# Time taken to calculate seam: 0.17088723182678223
# Time taken to convert boundary vertices to array: 1.5631158351898193
# Time taken to convert seam voxels to graph indices: 0.014582157135009766
# Time taken to update weights:  11.62621784210205
# Time taken to update weights outside fxn: 11.629797220230103
# Sum of overlap: 0
# Iteration: 0
# Time taken to calculate max flow push relabel: 30.2525851726532
# Time taken to calculate max flow: 0.16325998306274414 flow: 25564
# Time taken to calculate max flow and min cut: 0.8815698623657227
# edges that cross the partition: 12452352
# boundary vertices: 26587
# Time taken to calculate seam: 0.17076897621154785
# Time taken to convert boundary vertices to array: 1.5747621059417725
# Time taken to convert seam voxels to graph indices: 0.014962911605834961
# Time taken to update weights:  11.361263990402222
# Time taken to update weights outside fxn: 11.36509108543396
# Sum of overlap: 0
# Iteration: 1
# Time taken to calculate max flow push relabel: 29.913671016693115
# Time taken to calculate max flow: 0.17026400566101074 flow: 28489
# Time taken to calculate max flow and min cut: 0.8459227085113525
# edges that cross the partition: 12452352
# boundary vertices: 27691
# Time taken to calculate seam: 0.17103791236877441
# Time taken to convert boundary vertices to array: 1.6043829917907715
# Time taken to convert seam voxels to graph indices: 0.015074968338012695
# Time taken to update weights:  12.551630020141602
# Time taken to update weights outside fxn: 12.55601191520691
# Sum of overlap: 537
# Iteration: 2
# Time taken to calculate max flow push relabel: 29.341968059539795
# Time taken to calculate max flow: 0.16639423370361328 flow: 29740
# Time taken to calculate max flow and min cut: 0.9685282707214355
# edges that cross the partition: 12452352
# boundary vertices: 26010
# Time taken to calculate seam: 0.16750097274780273
# Time taken to convert boundary vertices to array: 1.5714950561523438
# Time taken to convert seam voxels to graph indices: 0.014495849609375
# Time taken to update weights:  12.36465573310852
# Time taken to update weights outside fxn: 12.369170188903809
# Sum of overlap: 126
# Iteration: 3
# Time taken to calculate max flow push relabel: 26.50860595703125
# Time taken to calculate max flow: 0.16494488716125488 flow: 30253
# Time taken to calculate max flow and min cut: 0.889941930770874
# edges that cross the partition: 12452352
# boundary vertices: 28132
# Time taken to calculate seam: 0.17169189453125
# Time taken to convert boundary vertices to array: 1.5858988761901855
# Time taken to convert seam voxels to graph indices: 0.014379024505615234
# Time taken to update weights:  11.235128164291382
# Time taken to update weights outside fxn: 11.239815950393677
# Sum of overlap: 0
# Iteration: 4
# Time taken to calculate max flow push relabel: 22.173542737960815
# Time taken to calculate max flow: 0.1640000343322754 flow: 31594
# Time taken to calculate max flow and min cut: 0.8457050323486328
# edges that cross the partition: 12452352
# boundary vertices: 27208
# Time taken to calculate seam: 0.16227293014526367
# Time taken to convert boundary vertices to array: 1.5703980922698975
# Time taken to convert seam voxels to graph indices: 0.014864921569824219
# Time taken to update weights:  11.395527124404907
# Time taken to update weights outside fxn: 11.400114059448242
# Sum of overlap: 425
# Iteration: 5
# Time taken to calculate max flow push relabel: 26.70184016227722
# Time taken to calculate max flow: 0.16848492622375488 flow: 32539
# Time taken to calculate max flow and min cut: 0.8837850093841553
# edges that cross the partition: 12452352
# boundary vertices: 27964
# Time taken to calculate seam: 0.17741084098815918
# Time taken to convert boundary vertices to array: 1.595797061920166
# Time taken to convert seam voxels to graph indices: 0.014861106872558594
# Time taken to update weights:  11.301238059997559
# Time taken to update weights outside fxn: 11.305793046951294
# Sum of overlap: 671
# Iteration: 6
# Time taken to calculate max flow push relabel: 36.26646089553833
# Time taken to calculate max flow: 0.165999174118042 flow: 33115
# Time taken to calculate max flow and min cut: 0.9661791324615479
# edges that cross the partition: 12452352
# boundary vertices: 26066
# Time taken to calculate seam: 0.16990113258361816
# Time taken to convert boundary vertices to array: 1.5782029628753662
# Time taken to convert seam voxels to graph indices: 0.015820980072021484
# Time taken to update weights:  11.03831696510315
# Time taken to update weights outside fxn: 11.042001008987427
# Sum of overlap: 671
# Iteration: 7
# Time taken to calculate max flow push relabel: 32.2416729927063
# Time taken to calculate max flow: 0.1649470329284668 flow: 35302
# Time taken to calculate max flow and min cut: 0.8695399761199951
# edges that cross the partition: 12452352
# boundary vertices: 27262
# Time taken to calculate seam: 0.17698097229003906
# Time taken to convert boundary vertices to array: 1.5944111347198486
# Time taken to convert seam voxels to graph indices: 0.014765024185180664
# Time taken to update weights:  12.424384832382202
# Time taken to update weights outside fxn: 12.429208040237427
# Sum of overlap: 181
# Iteration: 8
# Time taken to calculate max flow push relabel: 35.57990908622742
# Time taken to calculate max flow: 0.165755033493042 flow: 37273
# Time taken to calculate max flow and min cut: 0.9344761371612549
# edges that cross the partition: 12452352
# boundary vertices: 27460
# Time taken to calculate seam: 0.17824411392211914
# Time taken to convert boundary vertices to array: 1.6135649681091309
# Time taken to convert seam voxels to graph indices: 0.01507711410522461
# Time taken to update weights:  11.480287075042725
# Time taken to update weights outside fxn: 11.484764099121094
# Sum of overlap: 235
# Iteration: 9
# Time taken to calculate max flow push relabel: 33.47892189025879
# Time taken to calculate max flow: 0.16120195388793945 flow: 38758
# Time taken to calculate max flow and min cut: 0.9502320289611816
# edges that cross the partition: 12452352
# boundary vertices: 27091
# Time taken to calculate seam: 0.1741352081298828
# Time taken to convert boundary vertices to array: 1.564969778060913
# Time taken to convert seam voxels to graph indices: 0.014927148818969727
# Time taken to update weights:  10.922992944717407
# Time taken to update weights outside fxn: 10.926880121231079
# Sum of overlap: 906
# Iteration: 10
# Time taken to calculate max flow push relabel: 29.905673027038574
# Time taken to calculate max flow: 0.1613931655883789 flow: 38776
# Time taken to calculate max flow and min cut: 0.8615190982818604
# edges that cross the partition: 12452352
# boundary vertices: 27996
# Time taken to calculate seam: 0.17554998397827148
# Time taken to convert boundary vertices to array: 1.5628221035003662
# Time taken to convert seam voxels to graph indices: 0.014234781265258789
# Time taken to update weights:  12.252300024032593
# Time taken to update weights outside fxn: 12.256266117095947
# Sum of overlap: 1114
# Iteration: 11
# Time taken to calculate max flow push relabel: 35.56838083267212
# Time taken to calculate max flow: 0.16069412231445312 flow: 39991
# Time taken to calculate max flow and min cut: 0.9932892322540283
# edges that cross the partition: 12452352
# boundary vertices: 24909
# Time taken to calculate seam: 0.17177200317382812
# Time taken to convert boundary vertices to array: 1.5657680034637451
# Time taken to convert seam voxels to graph indices: 0.014745950698852539
# Time taken to update weights:  11.562788009643555
# Time taken to update weights outside fxn: 11.56657099723816
# Sum of overlap: 725
# Iteration: 12
# Time taken to calculate max flow push relabel: 31.297631978988647
# Time taken to calculate max flow: 0.16094589233398438 flow: 42475
# Time taken to calculate max flow and min cut: 0.9405770301818848
# edges that cross the partition: 12452352
# boundary vertices: 28142
# Time taken to calculate seam: 0.17682290077209473
# Time taken to convert boundary vertices to array: 1.5611968040466309
# Time taken to convert seam voxels to graph indices: 0.014729976654052734
# Time taken to update weights:  12.264366149902344
# Time taken to update weights outside fxn: 12.268024682998657
# Sum of overlap: 1077
# Iteration: 13
# Time taken to calculate max flow push relabel: 28.36049199104309
# Time taken to calculate max flow: 0.16132283210754395 flow: 45688
# Time taken to calculate max flow and min cut: 0.8975629806518555
# edges that cross the partition: 12452352
# boundary vertices: 27707
# Time taken to calculate seam: 0.16530513763427734
# Time taken to convert boundary vertices to array: 1.5508251190185547
# Time taken to convert seam voxels to graph indices: 0.014466047286987305
# Time taken to update weights:  11.204874038696289
# Time taken to update weights outside fxn: 11.209064960479736
# Sum of overlap: 1311
# Iteration: 14
# Time taken to calculate max flow push relabel: 31.647987842559814
# Time taken to calculate max flow: 0.1606440544128418 flow: 47866
# Time taken to calculate max flow and min cut: 1.0234370231628418
# edges that cross the partition: 12452352
# boundary vertices: 24219
# Time taken to calculate seam: 0.17634201049804688
# Time taken to convert boundary vertices to array: 1.5642366409301758
# Time taken to convert seam voxels to graph indices: 0.014541864395141602
# Time taken to update weights:  10.882860898971558
# Time taken to update weights outside fxn: 10.886482000350952
# Sum of overlap: 776
# Iteration: 15
# Time taken to calculate max flow push relabel: 26.85962963104248
# Time taken to calculate max flow: 0.16109895706176758 flow: 49792
# Time taken to calculate max flow and min cut: 0.917431116104126
# edges that cross the partition: 12452352
# boundary vertices: 28516
# Time taken to calculate seam: 0.16238617897033691
# Time taken to convert boundary vertices to array: 1.5545368194580078
# Time taken to convert seam voxels to graph indices: 0.014553070068359375
# Time taken to update weights:  12.04026174545288
# Time taken to update weights outside fxn: 12.04437518119812
# Sum of overlap: 2555
# Iteration: 16
# Time taken to calculate max flow push relabel: 37.5415780544281
# Time taken to calculate max flow: 0.16006708145141602 flow: 51736
# Time taken to calculate max flow and min cut: 0.9523890018463135
# edges that cross the partition: 12452352
# boundary vertices: 27483
# Time taken to calculate seam: 0.16482281684875488
# Time taken to convert boundary vertices to array: 1.5634691715240479
# Time taken to convert seam voxels to graph indices: 0.015079021453857422
# Time taken to update weights:  10.884469032287598
# Time taken to update weights outside fxn: 10.888779878616333
# Sum of overlap: 2355
# Iteration: 17
# Time taken to calculate max flow push relabel: 30.456237077713013
# Time taken to calculate max flow: 0.1610240936279297 flow: 53383
# Time taken to calculate max flow and min cut: 0.8747639656066895
# edges that cross the partition: 12452352
# boundary vertices: 29234
# Time taken to calculate seam: 0.16605710983276367
# Time taken to convert boundary vertices to array: 1.5600152015686035
# Time taken to convert seam voxels to graph indices: 0.014804840087890625
# Time taken to update weights:  10.79693603515625
# Time taken to update weights outside fxn: 10.801307201385498
# Sum of overlap: 2130
# Iteration: 18
# Time taken to calculate max flow push relabel: 31.980906009674072
# Time taken to calculate max flow: 0.16164612770080566 flow: 56551
# Time taken to calculate max flow and min cut: 0.9365901947021484
# edges that cross the partition: 12452352
# boundary vertices: 27211
# Time taken to calculate seam: 0.16379404067993164
# Time taken to convert boundary vertices to array: 1.5658049583435059
# Time taken to convert seam voxels to graph indices: 0.014400959014892578
# Time taken to update weights:  12.605763912200928
# Time taken to update weights outside fxn: 12.610466003417969
# Sum of overlap: 1348
# Iteration: 19
# Time taken to calculate max flow push relabel: 28.171334981918335
# Time taken to calculate max flow: 0.16118311882019043 flow: 57325
# Time taken to calculate max flow and min cut: 0.9013848304748535
# edges that cross the partition: 12452352
# boundary vertices: 27421
# Time taken to calculate seam: 0.16253900527954102
# Time taken to convert boundary vertices to array: 1.5618839263916016
# Time taken to convert seam voxels to graph indices: 0.014821290969848633
# Time taken to update weights:  10.923786878585815
# Time taken to update weights outside fxn: 10.92872405052185
# Sum of overlap: 1920
# Iteration: 20
# Time taken to calculate max flow push relabel: 34.69300103187561
# Time taken to calculate max flow: 0.16205286979675293 flow: 60286
# Time taken to calculate max flow and min cut: 0.920316219329834
# edges that cross the partition: 12452352
# boundary vertices: 28264
# Time taken to calculate seam: 0.1611778736114502
# Time taken to convert boundary vertices to array: 1.547788143157959
# Time taken to convert seam voxels to graph indices: 0.014631986618041992
# Time taken to update weights:  10.950347900390625
# Time taken to update weights outside fxn: 10.954780101776123
# Sum of overlap: 3767
# Iteration: 21
# Time taken to calculate max flow push relabel: 28.553882837295532
# Time taken to calculate max flow: 0.16020989418029785 flow: 68863
# Time taken to calculate max flow and min cut: 0.9108309745788574
# edges that cross the partition: 12452352
# boundary vertices: 28911
# Time taken to calculate seam: 0.1651449203491211
# Time taken to convert boundary vertices to array: 1.547234058380127
# Time taken to convert seam voxels to graph indices: 0.015253067016601562
# Time taken to update weights:  11.057523012161255
# Time taken to update weights outside fxn: 11.061649322509766
# Sum of overlap: 2694
# Iteration: 22
# Time taken to calculate max flow push relabel: 47.163761138916016
# Time taken to calculate max flow: 0.16210222244262695 flow: 70141
# Time taken to calculate max flow and min cut: 0.9561159610748291
# edges that cross the partition: 12452352
# boundary vertices: 27814
# Time taken to calculate seam: 0.16683697700500488
# Time taken to convert boundary vertices to array: 1.5634939670562744
# Time taken to convert seam voxels to graph indices: 0.014595985412597656
# Time taken to update weights:  11.680866956710815
# Time taken to update weights outside fxn: 11.685282945632935
# Sum of overlap: 2693
# Iteration: 23
# Time taken to calculate max flow push relabel: 46.75188612937927
# Time taken to calculate max flow: 0.16053295135498047 flow: 80356
# Time taken to calculate max flow and min cut: 0.9402849674224854
# edges that cross the partition: 12452352
# boundary vertices: 27533
# Time taken to calculate seam: 0.16494178771972656
# Time taken to convert boundary vertices to array: 1.5532970428466797
# Time taken to convert seam voxels to graph indices: 0.01491689682006836
# Time taken to update weights:  10.9032621383667
# Time taken to update weights outside fxn: 10.907119989395142
# Sum of overlap: 2716
# Iteration: 24
# Time taken to calculate max flow push relabel: 28.76371192932129
# Time taken to calculate max flow: 0.15917491912841797 flow: 100042033
# Time taken to calculate max flow and min cut: 0.9080100059509277
# edges that cross the partition: 12452352
# boundary vertices: 29264
# Time taken to calculate seam: 0.1644001007080078
# Time taken to convert boundary vertices to array: 1.5581719875335693
# Time taken to convert seam voxels to graph indices: 0.014627218246459961
# Time taken to update weights:  10.964777946472168
# Time taken to update weights outside fxn: 10.969789981842041
# Sum of overlap: 1945
# Iteration: 25
# Time taken to calculate max flow push relabel: 36.692485332489014
# Time taken to calculate max flow: 0.15952682495117188 flow: 200049295
# Time taken to calculate max flow and min cut: 0.9424266815185547
# edges that cross the partition: 12452352
# boundary vertices: 29676
# Time taken to calculate seam: 0.1654062271118164
# Time taken to convert boundary vertices to array: 1.5646178722381592
# Time taken to convert seam voxels to graph indices: 0.014787912368774414
# Time taken to update weights:  12.611968994140625
# Time taken to update weights outside fxn: 12.615926027297974
# Sum of overlap: 2509
# Iteration: 26
# Time taken to calculate max flow push relabel: 36.32396912574768
# Time taken to calculate max flow: 0.16273903846740723 flow: 300052129
# Time taken to calculate max flow and min cut: 0.9224138259887695
# edges that cross the partition: 12452352
# boundary vertices: 27889
# Time taken to calculate seam: 0.16922211647033691
# Time taken to convert boundary vertices to array: 1.5669758319854736
# Time taken to convert seam voxels to graph indices: 0.014458894729614258
# Time taken to update weights:  10.941499948501587
# Time taken to update weights outside fxn: 10.945947170257568
# Sum of overlap: 2641
# Iteration: 27
# Time taken to calculate max flow push relabel: 40.81474709510803
# Time taken to calculate max flow: 0.1624588966369629 flow: 300070417
# Time taken to calculate max flow and min cut: 0.8951208591461182
# edges that cross the partition: 12452352
# boundary vertices: 28640
# Time taken to calculate seam: 0.16713237762451172
# Time taken to convert boundary vertices to array: 1.5687549114227295
# Time taken to convert seam voxels to graph indices: 0.014505863189697266
# Time taken to update weights:  11.458973169326782
# Time taken to update weights outside fxn: 11.463433027267456
# Sum of overlap: 3769
# Iteration: 28
# Time taken to calculate max flow push relabel: 41.79753303527832
# Time taken to calculate max flow: 0.16135811805725098 flow: 300072775
# Time taken to calculate max flow and min cut: 0.9013798236846924
# edges that cross the partition: 12452352
# boundary vertices: 28339
# Time taken to calculate seam: 0.16632819175720215
# Time taken to convert boundary vertices to array: 1.5547351837158203
# Time taken to convert seam voxels to graph indices: 0.014667034149169922
# Time taken to update weights:  11.698371171951294
# Time taken to update weights outside fxn: 11.702551126480103
# Sum of overlap: 3561
# Iteration: 29
# Time taken to calculate max flow push relabel: 48.27583885192871
# Time taken to calculate max flow: 0.16145896911621094 flow: 700051567
# Time taken to calculate max flow and min cut: 1.0234649181365967
# edges that cross the partition: 12452352
# boundary vertices: 26238
# Time taken to calculate seam: 0.16294193267822266
# Time taken to convert boundary vertices to array: 1.556607961654663
# Time taken to convert seam voxels to graph indices: 0.014566898345947266
# Time taken to update weights:  11.73150897026062
# Time taken to update weights outside fxn: 11.737044095993042
# Sum of overlap: 2292
# Iteration: 30
# Time taken to calculate max flow push relabel: 41.94740414619446
# Time taken to calculate max flow: 0.160675048828125 flow: 800056021
# Time taken to calculate max flow and min cut: 0.9404957294464111
# edges that cross the partition: 12452352
# boundary vertices: 29519
# Time taken to calculate seam: 0.16326498985290527
# Time taken to convert boundary vertices to array: 1.557157278060913
# Time taken to convert seam voxels to graph indices: 0.015040159225463867
# Time taken to update weights:  11.223046779632568
# Time taken to update weights outside fxn: 11.22810435295105
# Sum of overlap: 4223
# Iteration: 31

# %%
# Create the new boundary array initialized to zeros
boundary_array = np.zeros_like(original_boundary_array)
boundary_array[original_boundary_array > 0] = 1
boundary_array[rotated_boundary_array > 0] = 2
if reduced_mask_data_t.shape[0] <= 64:

    # Plot the 3d boundary array with plotly
    showAll = False
    # Define the grid dimensions
    x_dim, y_dim, z_dim = boundary_array.shape
    x, y, z = np.indices((x_dim, y_dim, z_dim))

    # Flatten the data
    x, y, z = x.flatten(), y.flatten(), z.flatten()
    if showAll:
        # vis_data = np.copy(test_data)
        vis_data = np.where(reduced_mask_data_t != 0, 1, 0)
        vis_data[boundary_array == 1] = 2
    else:
        vis_data = boundary_array

    values = vis_data.flatten()

    # Calculate the linear index using C-style row-major order
    index = lambda i, j, k: i * y_dim * z_dim + j * z_dim + k
    indices = [index(i, j, k) for i, j, k in zip(x, y, z)]

    # Create a scatter plot
    fig = go.Figure(data=[go.Scatter3d(
        x=x,
        y=y,
        z=z,
        mode='markers',
        marker=dict(
            size=1,
            color=values,
            # colorscale='Viridis',
            colorbar=dict(title='Color Scale'),
            # opacity=0.8
            colorscale=[[0, 'rgba(0, 0, 0, 0)'], [0.5, 'blue'], [1.0, 'red']],  # Blue for 1, transparent for 0
            # opacity=[1 if value == 1 else 0 for value in values]  # Fully opaque for 1, fully transparent for 0
        )
    )])

    # Update layout to remove background grids and keep axes fixed
    fig.update_layout(scene=dict(
        xaxis=dict(showbackground=False, showgrid=False, showline=True, zeroline=True),
        yaxis=dict(showbackground=False, showgrid=False, showline=True, zeroline=True),
        zaxis=dict(showbackground=False, showgrid=False, showline=True, zeroline=True)
    ))

    fig.show()

# %%
# boundary_array = np.where(boundary_array != 0, 1, 0)
boundary_array = rotated_boundary_array
boundary_array = np.where(boundary_array != 0, 1, 0)
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(mark_boundaries_color(reduced_raw_data_t[:,slice_index,:], boundary_array[:,slice_index,:]))
    elif axis == 2:
        plt.imshow(mark_boundaries_color(reduced_raw_data_t[:,:,slice_index], boundary_array[:,:,slice_index]))
    else:
        plt.imshow(mark_boundaries_color(reduced_raw_data_t[slice_index,:,:], boundary_array[slice_index,:,:]))
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()
 
print(reduced_raw_data_t.max(), reduced_raw_data_t.min())
# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=reduced_raw_data.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# 65535 4421
# interactive(children=(IntSlider(value=0, description='slice_index', max=127), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
def remove_voxels(data_array, boundary_array, num_voxels_to_remove, direction='x'):
    """
    Removes a specified number of voxels from each row in the given direction
    based on a boundary mask array.
    
    Parameters:
    data_array (np.ndarray): The original 3D array from which voxels are to be removed.
    boundary_array (np.ndarray): The boundary mask 3D array specifying the voxels to be removed.
    num_voxels_to_remove (int): Number of voxels to be removed from each row.
    direction (str): The direction in which voxels are to be removed ('x', 'y', 'z').
    
    Returns:
    np.ndarray: The resulting 3D array with the specified voxels removed.
    """
    assert data_array.shape == boundary_array.shape, "Data array and boundary array must have the same shape."
    assert direction in ['x', 'y', 'z'], "Direction must be 'x', 'y', or 'z'."
    
    if direction == 'x':
        new_shape = (data_array.shape[0], data_array.shape[1], data_array.shape[2] - num_voxels_to_remove)
        result_array = np.zeros(new_shape, dtype=data_array.dtype)
        for i in range(data_array.shape[0]):
            for j in range(data_array.shape[1]):
                data_row = data_array[i, j, :]
                boundary_row = boundary_array[i, j, :]
                keep_indices = np.where(boundary_row == 0)[0]
                keep_indices = keep_indices[:new_shape[2]]  # Only keep up to the new size
                result_array[i, j, :] = data_row[keep_indices][:new_shape[2]]
    
    elif direction == 'y':
        new_shape = (data_array.shape[0], data_array.shape[1] - num_voxels_to_remove, data_array.shape[2])
        result_array = np.zeros(new_shape, dtype=data_array.dtype)
        for i in range(data_array.shape[0]):
            for k in range(data_array.shape[2]):
                data_row = data_array[i, :, k]
                boundary_row = boundary_array[i, :, k]
                keep_indices = np.where(boundary_row == 0)[0]
                keep_indices = keep_indices[:new_shape[1]]  # Only keep up to the new size
                result_array[i, :, k] = data_row[keep_indices][:new_shape[1]]
    
    elif direction == 'z':
        new_shape = (data_array.shape[0] - num_voxels_to_remove, data_array.shape[1], data_array.shape[2])
        result_array = np.zeros(new_shape, dtype=data_array.dtype)
        for j in range(data_array.shape[1]):
            for k in range(data_array.shape[2]):
                data_row = data_array[:, j, k]
                boundary_row = boundary_array[:, j, k]
                keep_indices = np.where(boundary_row == 0)[0]
                keep_indices = keep_indices[:new_shape[0]]  # Only keep up to the new size
                result_array[:, j, k] = data_row[keep_indices][:new_shape[0]]
    
    return result_array

# %%
print(iters)
densified_data = remove_voxels(reduced_raw_data_t, boundary_array, iters, direction='x')
densified_label = remove_voxels(reduced_mask_data_t, boundary_array, iters, direction='x')
print(densified_data.shape, densified_label.shape)
# Out:
# 32
# (128, 128, 96) (128, 128, 96)

# %%
#save teh boundary array, densified data and densified label as nrrd files in /output
nrrd.write(f"{current_directory}/output/boundary_array.nrrd", boundary_array)
nrrd.write(f"{current_directory}/output/densified_data.nrrd", densified_data)
nrrd.write(f"{current_directory}/output/densified_label.nrrd", densified_label)

# %%
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(densified_data[:,slice_index,:],cmap='gray')
    elif axis == 2:
        plt.imshow(densified_data[:,:,slice_index],cmap='gray')
    else:
        plt.imshow(densified_data[slice_index,:,:],cmap='gray')
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()
 
print(reduced_raw_data_t.max(), reduced_raw_data_t.min())
# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=densified_data.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# 65535 4421
# interactive(children=(IntSlider(value=0, description='slice_index', max=127), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(densified_label[:,slice_index,:])
    elif axis == 2:
        plt.imshow(densified_label[:,:,slice_index])
    else:
        plt.imshow(densified_label[slice_index,:,:])
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()
 
print(reduced_raw_data_t.max(), reduced_raw_data_t.min())
# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=densified_data.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# 65535 4421
# interactive(children=(IntSlider(value=0, description='slice_index', max=127), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>
