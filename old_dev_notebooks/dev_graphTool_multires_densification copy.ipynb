# %%
import nrrd
import numpy as np
import os
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider
from skimage.segmentation import mark_boundaries
import cv2
from scipy import ndimage as ndi
from helper import *
import graph_tool.all as gt
import plotly.graph_objects as go
import time
from datetime import datetime


current_directory = os.getcwd()
label_path = f"{current_directory}/data/label/manual_2_label.nrrd"
raw_data_path = f"{current_directory}/data/raw/manual_2_raw.nrrd"

mask_data, mask_header = nrrd.read(label_path)
raw_data, raw_header = nrrd.read(raw_data_path)

# %%
#rotate the data for best cut angle and calculate reduced data representations
# axis = 1 #0 for x, 1 for y and 2 for z
# k = 1 # number of times to rotate the array
# mask_data = np.rot90(mask_data, k, axes=(axis, (axis+1)%3))
# raw_data = np.rot90(raw_data, k, axes=(axis, (axis+1)%3))

reduced_mask_data = coarsen_image(mask_data, 3)
reduced_raw_data = coarsen_image(raw_data, 3)
#[0] is full res, each further index is 2x lower res, 256, 128, 64, 32

# %%
#create reduced graph
res_index = 2
rotated_directed_graph, r_src, r_tgt, rotated_weights, x_pos, y_pos, z_pos = create_masked_directed_energy_graph_from_mask(reduced_mask_data[res_index])
# Out:
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0748591423034668
# Time taken to add edges to graph: 2.0179619789123535
# Time taken to add source and sink nodes: 0.0815286636352539

# %%
def calculate_seam_iter(directed_graph, src, tgt, weights, test_size, x_pos, y_pos, z_pos):
    # Compute the residual capactiy of the edges
    stime = time.time()
    res = gt.boykov_kolmogorov_max_flow(directed_graph, src, tgt, weights) #time complexity: edges * vertices^2 * abs(min cut) 
    print("Time taken to calculate max flow boykov:", time.time()-stime)
    # sptime = time.time()
    # res = gt.push_relabel_max_flow(directed_graph, src, tgt, weights) #time complexity: vertices^3 <- scales better for our graph
    # print("Time taken to calculate max flow push relabel:", time.time()-sptime)
    stime = time.time()
    #use the residual graph to get the max flow
    flow = sum(weights[e] - res[e] for e in tgt.in_edges())
    # print("The maximum flow from source to sink is:", flow)
    print("Time taken to calculate max flow:", time.time()-stime, "flow:", flow)
    stime = time.time()
    # Determine the minimum cut partition
    part = gt.min_st_cut(directed_graph, src, weights, res)
    # print("The number of vertices in the partiton:", sum(part))
    print("Time taken to calculate max flow and min cut:", time.time()-stime)
    # Find the boundary vertices
    stime = time.time()
    boundary_vertices = find_boundary_vertices(np.array(directed_graph.get_edges()), part)
    # print("Number of boundary vertices:", len(boundary_vertices))
    print("Time taken to calculate seam:", time.time()-stime)

    shape = (test_size, test_size, test_size)

    # Convert the boundary vertices to a 3D array
    stime = time.time()
    boundary_array = boundary_vertices_to_array_masked(boundary_vertices, shape, 'x', x_pos, y_pos, z_pos)
    # print("Boundary points marked:", np.sum(boundary_array))
    print("Time taken to convert boundary vertices to array:", time.time()-stime)

    return boundary_array, flow

# %%
boundary_array, flow = calculate_seam_iter(rotated_directed_graph, r_src, r_tgt, rotated_weights, reduced_mask_data[res_index].shape[0], x_pos, y_pos, z_pos)
b_arr_up = upscale_and_dilate_3d(boundary_array, upscale_factor=4, dilation_amount=1)
print(b_arr_up.shape)
# Out:
# Time taken to calculate max flow boykov: 0.8359119892120361
# Time taken to calculate max flow: 0.03977799415588379 flow: 10045
# Time taken to calculate max flow and min cut: 0.09181094169616699
# edges that cross the partition: 1540352
# boundary vertices: 7653
# Time taken to calculate seam: 0.01895594596862793
# Time taken to convert boundary vertices to array: 0.02890777587890625
# (256, 256, 256)

# %%
# copying and masking the high res data for masked graph creation
res_index = 0
masked_array = reduced_mask_data[res_index].copy()
print(masked_array.shape, b_arr_up.shape)
masked_array[b_arr_up == 0] = -1

masked_graph, masked_src, masked_sink, masked_weights, x_pos, y_pos, z_pos = create_masked_directed_energy_graph_from_mask(masked_array)
# Out:
# (256, 256, 256) (256, 256, 256)
# 256 256 256
# /var/folders/0t/my3c3j251vl2s6y6tvgd80ph0000gn/T/ipykernel_19351/3695038853.py:5: DeprecationWarning: NumPy will stop allowing conversion of out-of-bound Python integers to integer arrays.  The conversion of -1 to uint8 will fail in the future.
# For the old behavior, usually:
#     np.array(value).astype(dtype)
# will give the desired result (the cast overflows).
#   masked_array[b_arr_up == 0] = -1
# Time taken to add vertices to coord_to_vertex: 76.75076198577881
# Time taken to add edges to graph: 131.90148305892944
# Time taken to add source and sink nodes: 1.5832099914550781

# %%
#plot masked array
print(masked_graph.num_vertices(), masked_graph.num_edges(), masked_src, masked_sink)
res_i = 0
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(masked_array[:,slice_index,:])
    elif axis == 2:
        plt.imshow(masked_array[:,:,slice_index])
    else:
        plt.imshow(masked_array[slice_index,:,:])
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=masked_array.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# 16777218 100140032 16777216 16777217
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
#plot label ontop of raw data
res_i = 0
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(mark_boundaries_color(b_arr_up[:,slice_index,:], reduced_mask_data[res_i][:,slice_index,:]))
    elif axis == 2:
        plt.imshow(mark_boundaries_color(b_arr_up[:,:,slice_index], reduced_mask_data[res_i][:,:,slice_index]))
    else:
        plt.imshow(mark_boundaries_color(b_arr_up[slice_index,:,:], reduced_mask_data[res_i][slice_index,:,:]))
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=b_arr_up.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
boundary_array, flow = calculate_seam_iter(masked_graph, masked_src, masked_sink, masked_weights, masked_array.shape[0], x_pos, y_pos, z_pos)
# Out:
# Time taken to calculate max flow boykov: 30.87933588027954
# Time taken to calculate max flow: 0.6471571922302246 flow: 139426
# Time taken to calculate max flow and min cut: 16.496016025543213
# edges that cross the partition: 100140032
# boundary vertices: 123460
# Time taken to calculate seam: 1.5263051986694336
# Time taken to convert boundary vertices to array: 0.4662909507751465

# %%
print("flow:", flow)
print("boundary_array:", np.sum(boundary_array))
# Out:
# flow: 139426
# boundary_array: 65536

# %%
#plot full res boundary array
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(boundary_array[:,slice_index,:])
    elif axis == 2:
        plt.imshow(boundary_array[:,:,slice_index])
    else:
        plt.imshow(boundary_array[slice_index,:,:])
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=boundary_array.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
#plot seam ontop of raw data
res_i = 0
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(mark_boundaries_color(boundary_array[:,slice_index,:], reduced_mask_data[res_i][:,slice_index,:]))
    elif axis == 2:
        plt.imshow(mark_boundaries_color(boundary_array[:,:,slice_index], reduced_mask_data[res_i][:,:,slice_index]))
    else:
        plt.imshow(mark_boundaries_color(boundary_array[slice_index,:,:], reduced_mask_data[res_i][slice_index,:,:]))
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=b_arr_up.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
def multi_res_seam_iter(res_index, mask_array_data, b_arr_up):
    masked_array = mask_array_data[res_index].copy()
    masked_array[b_arr_up == 0] = -1
    stime= time.time()
    directed_graph, src, tgt, weights, x_pos, y_pos, z_pos = create_masked_directed_energy_graph_from_mask(masked_array)
    print(f"Time taken to create graph {res_index}:", time.time()-stime)
    boundary_array, flow = calculate_seam_iter(directed_graph, src, tgt, weights, masked_array.shape[0], x_pos, y_pos, z_pos)
    return boundary_array

def multi_res_seam_calculation(mask_array_data, res_index=3, upscale_factor=2, dilation_amount=1):
    stime= time.time()
    directed_graph, src, tgt, weights, x_pos, y_pos, z_pos = create_masked_directed_energy_graph_from_mask(mask_array_data[res_index])
    print(f"Time taken to create graph {res_index}:", time.time()-stime)
    boundary_array, flow = calculate_seam_iter(directed_graph, src, tgt, weights, mask_array_data[res_index].shape[0], x_pos, y_pos, z_pos)
    b_arr_up = upscale_and_dilate_3d(boundary_array, upscale_factor=2, dilation_amount=dilation_amount)
    for i in range(res_index-1, -1, -1):
        boundary_array = multi_res_seam_iter(i, mask_array_data, b_arr_up)
        b_arr_up = upscale_and_dilate_3d(boundary_array, upscale_factor=upscale_factor, dilation_amount=dilation_amount)
    return boundary_array

# %%
def remove_voxels(data_array, mask_array, boundary_array, num_voxels_to_remove=1, direction='x'):
    """
    Removes a specified number of voxels from each row in the given direction
    based on a boundary mask array.
    
    Parameters:
    data_array (np.ndarray): The original 3D array from which voxels are to be removed.
    boundary_array (np.ndarray): The boundary mask 3D array specifying the voxels to be removed.
    num_voxels_to_remove (int): Number of voxels to be removed from each row.
    direction (str): The direction in which voxels are to be removed ('x', 'y', 'z').
    
    Returns:
    np.ndarray: The resulting 3D array with the specified voxels removed.
    """
    assert data_array.shape == boundary_array.shape, f"Data array and boundary array must have the same shape. {data_array.shape} != {boundary_array.shape}"
    assert mask_array.shape == boundary_array.shape, f"Mask array and boundary array must have the same shape. {mask_array.shape} != {boundary_array.shape}"
    assert direction in ['x', 'y', 'z'], "Direction must be 'x', 'y', or 'z'."
    
    if direction == 'x':
        new_shape = (data_array.shape[0], data_array.shape[1], data_array.shape[2] - num_voxels_to_remove)
        result_data_array = np.zeros(new_shape, dtype=data_array.dtype)
        result_mask_array = np.zeros(new_shape, dtype=mask_array.dtype)
        for i in range(data_array.shape[0]):
            for j in range(data_array.shape[1]):
                data_row = data_array[i, j, :]
                boundary_row = boundary_array[i, j, :]
                keep_indices = np.where(boundary_row == 0)[0]
                keep_indices = keep_indices[:new_shape[2]]  # Only keep up to the new size
                result_data_array[i, j, :] = data_row[keep_indices][:new_shape[2]]
                result_mask_array[i, j, :] = mask_array[i, j, keep_indices][:new_shape[2]]
        
        # Create padded arrays with -1
        padded_data_array = -np.ones_like(data_array, dtype=data_array.dtype)
        padded_mask_array = -np.ones_like(mask_array, dtype=mask_array.dtype)
        
        # Copy the result arrays into the padded arrays
        padded_data_array[:, :, :new_shape[2]] = result_data_array
        padded_mask_array[:, :, :new_shape[2]] = result_mask_array
    
    elif direction == 'y':
        new_shape = (data_array.shape[0], data_array.shape[1] - num_voxels_to_remove, data_array.shape[2])
        result_data_array = np.zeros(new_shape, dtype=data_array.dtype)
        result_mask_array = np.zeros(new_shape, dtype=mask_array.dtype)
        for i in range(data_array.shape[0]):
            for k in range(data_array.shape[2]):
                data_row = data_array[i, :, k]
                boundary_row = boundary_array[i, :, k]
                keep_indices = np.where(boundary_row == 0)[0]
                keep_indices = keep_indices[:new_shape[1]]  # Only keep up to the new size
                result_data_array[i, :, k] = data_row[keep_indices][:new_shape[1]]
                result_mask_array[i, :, k] = mask_array[i, keep_indices, k][:new_shape[1]]
        
        # Create padded arrays with -1
        padded_data_array = -np.ones_like(data_array, dtype=data_array.dtype)
        padded_mask_array = -np.ones_like(mask_array, dtype=mask_array.dtype)
        
        # Copy the result arrays into the padded arrays
        padded_data_array[:, :new_shape[1], :] = result_data_array
        padded_mask_array[:, :new_shape[1], :] = result_mask_array
    
    elif direction == 'z':
        new_shape = (data_array.shape[0] - num_voxels_to_remove, data_array.shape[1], data_array.shape[2])
        result_data_array = np.zeros(new_shape, dtype=data_array.dtype)
        result_mask_array = np.zeros(new_shape, dtype=mask_array.dtype)
        for j in range(data_array.shape[1]):
            for k in range(data_array.shape[2]):
                data_row = data_array[:, j, k]
                boundary_row = boundary_array[:, j, k]
                keep_indices = np.where(boundary_row == 0)[0]
                keep_indices = keep_indices[:new_shape[0]]  # Only keep up to the new size
                result_data_array[:, j, k] = data_row[keep_indices][:new_shape[0]]
                result_mask_array[:, j, k] = mask_array[keep_indices, j, k][:new_shape[0]]
        
        # Create padded arrays with -1
        padded_data_array = -np.ones_like(data_array, dtype=data_array.dtype)
        padded_mask_array = -np.ones_like(mask_array, dtype=mask_array.dtype)
        
        # Copy the result arrays into the padded arrays
        padded_data_array[:new_shape[0], :, :] = result_data_array
        padded_mask_array[:new_shape[0], :, :] = result_mask_array
    
    return padded_data_array, padded_mask_array

# %%
res_index = 3
mask_array_data = reduced_mask_data
raw_array_data = reduced_raw_data[0]
num_seams_to_remove = 80

boundary_arrays = []

for i in range(num_seams_to_remove):
    boundary_array = multi_res_seam_calculation(mask_array_data, res_index, dilation_amount=1)
    mask_array_data, raw_array_data = remove_voxels(mask_array_data[0], raw_array_data, boundary_array)
    mask_array_data = coarsen_image(mask_array_data, 3)
    boundary_arrays.append(boundary_array)

    #TODO: remove seam from mask_array_data
# Out:
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.13080501556396484
# Time taken to add edges to graph: 0.23699140548706055
# Time taken to add source and sink nodes: 0.01970505714416504
# Time taken to create graph 3: 0.39046406745910645
# Time taken to calculate max flow boykov: 0.04002189636230469
# Time taken to calculate max flow: 0.011615276336669922 flow: 2275
# Time taken to calculate max flow and min cut: 0.006891012191772461
# edges that cross the partition: 188544
# boundary vertices: 1615
# Time taken to calculate seam: 0.0036809444427490234
# Time taken to convert boundary vertices to array: 0.006754159927368164
# 64 64 64
# /var/folders/0t/my3c3j251vl2s6y6tvgd80ph0000gn/T/ipykernel_19351/3957142680.py:3: DeprecationWarning: NumPy will stop allowing conversion of out-of-bound Python integers to integer arrays.  The conversion of -1 to uint8 will fail in the future.
# For the old behavior, usually:
#     np.array(value).astype(dtype)
# will give the desired result (the cast overflows).
#   masked_array[b_arr_up == 0] = -1
# Time taken to add vertices to coord_to_vertex: 1.098560094833374
# Time taken to add edges to graph: 1.9038548469543457
# Time taken to add source and sink nodes: 0.08116507530212402
# Time taken to create graph 2: 3.100813865661621
# Time taken to calculate max flow boykov: 0.2896409034729004
# Time taken to calculate max flow: 0.04303121566772461 flow: 6535
# Time taken to calculate max flow and min cut: 0.0706169605255127
# edges that cross the partition: 1540352
# boundary vertices: 6422
# Time taken to calculate seam: 0.023509979248046875
# Time taken to convert boundary vertices to array: 0.025722980499267578
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 8.687899112701416
# Time taken to add edges to graph: 15.729487895965576
# Time taken to add source and sink nodes: 0.3307068347930908
# Time taken to create graph 1: 24.870909214019775
# Time taken to calculate max flow boykov: 2.7160048484802246
# Time taken to calculate max flow: 0.15847992897033691 flow: 24322
# Time taken to calculate max flow and min cut: 0.7896678447723389
# edges that cross the partition: 12452352
# boundary vertices: 25825
# Time taken to calculate seam: 0.16283178329467773
# Time taken to convert boundary vertices to array: 0.10097098350524902
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 75.40943694114685
# Time taken to add edges to graph: 129.95516705513
# Time taken to add source and sink nodes: 1.4982821941375732
# Time taken to create graph 0: 207.83830904960632
# Time taken to calculate max flow boykov: 30.637265920639038
# Time taken to calculate max flow: 0.6578550338745117 flow: 92959
# Time taken to calculate max flow and min cut: 14.096365690231323
# edges that cross the partition: 100140032
# boundary vertices: 103839
# Time taken to calculate seam: 1.344696044921875
# Time taken to convert boundary vertices to array: 0.4354698657989502
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.13191699981689453
# Time taken to add edges to graph: 0.2416379451751709
# Time taken to add source and sink nodes: 0.02016592025756836
# Time taken to create graph 3: 0.3964078426361084
# Time taken to calculate max flow boykov: 0.04040694236755371
# Time taken to calculate max flow: 0.01160883903503418 flow: 2464
# Time taken to calculate max flow and min cut: 0.006064176559448242
# edges that cross the partition: 188544
# boundary vertices: 1621
# Time taken to calculate seam: 0.0026111602783203125
# Time taken to convert boundary vertices to array: 0.00616002082824707
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.08066987991333
# Time taken to add edges to graph: 1.860875129699707
# Time taken to add source and sink nodes: 0.08353781700134277
# Time taken to create graph 2: 3.0417258739471436
# Time taken to calculate max flow boykov: 0.27771711349487305
# Time taken to calculate max flow: 0.04216599464416504 flow: 6571
# Time taken to calculate max flow and min cut: 0.06628990173339844
# edges that cross the partition: 1540352
# boundary vertices: 6395
# Time taken to calculate seam: 0.02130913734436035
# Time taken to convert boundary vertices to array: 0.025163888931274414
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 9.574364185333252
# Time taken to add edges to graph: 15.473486185073853
# Time taken to add source and sink nodes: 0.3420078754425049
# Time taken to create graph 1: 25.5134539604187
# Time taken to calculate max flow boykov: 2.9062273502349854
# Time taken to calculate max flow: 0.16501712799072266 flow: 24232
# Time taken to calculate max flow and min cut: 0.7941091060638428
# edges that cross the partition: 12452352
# boundary vertices: 25734
# Time taken to calculate seam: 0.1721479892730713
# Time taken to convert boundary vertices to array: 0.104949951171875
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 76.44281721115112
# Time taken to add edges to graph: 131.34350419044495
# Time taken to add source and sink nodes: 1.4815561771392822
# Time taken to create graph 0: 210.23851585388184
# Time taken to calculate max flow boykov: 29.4055438041687
# Time taken to calculate max flow: 0.6484072208404541 flow: 92752
# Time taken to calculate max flow and min cut: 13.78622817993164
# edges that cross the partition: 100140032
# boundary vertices: 103439
# Time taken to calculate seam: 1.3378300666809082
# Time taken to convert boundary vertices to array: 0.4334530830383301
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.12781691551208496
# Time taken to add edges to graph: 0.23277902603149414
# Time taken to add source and sink nodes: 0.01992511749267578
# Time taken to create graph 3: 0.383159875869751
# Time taken to calculate max flow boykov: 0.047625064849853516
# Time taken to calculate max flow: 0.011387825012207031 flow: 2626
# Time taken to calculate max flow and min cut: 0.006054878234863281
# edges that cross the partition: 188544
# boundary vertices: 1636
# Time taken to calculate seam: 0.0027289390563964844
# Time taken to convert boundary vertices to array: 0.006155967712402344
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.10239577293396
# Time taken to add edges to graph: 1.9692840576171875
# Time taken to add source and sink nodes: 0.08531403541564941
# Time taken to create graph 2: 3.174403190612793
# Time taken to calculate max flow boykov: 0.2925601005554199
# Time taken to calculate max flow: 0.042973995208740234 flow: 6652
# Time taken to calculate max flow and min cut: 0.06782984733581543
# edges that cross the partition: 1540352
# boundary vertices: 6455
# Time taken to calculate seam: 0.02266383171081543
# Time taken to convert boundary vertices to array: 0.02478480339050293
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 9.268172025680542
# Time taken to add edges to graph: 15.79994010925293
# Time taken to add source and sink nodes: 0.34776878356933594
# Time taken to create graph 1: 25.540819883346558
# Time taken to calculate max flow boykov: 2.7570407390594482
# Time taken to calculate max flow: 0.16220402717590332 flow: 24214
# Time taken to calculate max flow and min cut: 0.7810952663421631
# edges that cross the partition: 12452352
# boundary vertices: 26007
# Time taken to calculate seam: 0.16265487670898438
# Time taken to convert boundary vertices to array: 0.10185480117797852
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 76.75089001655579
# Time taken to add edges to graph: 130.7490429878235
# Time taken to add source and sink nodes: 1.4529669284820557
# Time taken to create graph 0: 209.91553282737732
# Time taken to calculate max flow boykov: 29.501521825790405
# Time taken to calculate max flow: 0.638923168182373 flow: 92455
# Time taken to calculate max flow and min cut: 13.93120527267456
# edges that cross the partition: 100140032
# boundary vertices: 104585
# Time taken to calculate seam: 1.4043519496917725
# Time taken to convert boundary vertices to array: 0.43769192695617676
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.12975478172302246
# Time taken to add edges to graph: 0.23525595664978027
# Time taken to add source and sink nodes: 0.019967079162597656
# Time taken to create graph 3: 0.3872251510620117
# Time taken to calculate max flow boykov: 0.07257819175720215
# Time taken to calculate max flow: 0.01184701919555664 flow: 2824
# Time taken to calculate max flow and min cut: 0.0066072940826416016
# edges that cross the partition: 188544
# boundary vertices: 1653
# Time taken to calculate seam: 0.003156900405883789
# Time taken to convert boundary vertices to array: 0.006108999252319336
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0466299057006836
# Time taken to add edges to graph: 1.8428730964660645
# Time taken to add source and sink nodes: 0.08324790000915527
# Time taken to create graph 2: 2.9895551204681396
# Time taken to calculate max flow boykov: 0.2821950912475586
# Time taken to calculate max flow: 0.04185223579406738 flow: 6895
# Time taken to calculate max flow and min cut: 0.06957101821899414
# edges that cross the partition: 1540352
# boundary vertices: 6468
# Time taken to calculate seam: 0.023329973220825195
# Time taken to convert boundary vertices to array: 0.024820804595947266
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 8.483453273773193
# Time taken to add edges to graph: 15.366655111312866
# Time taken to add source and sink nodes: 0.340770959854126
# Time taken to create graph 1: 24.313214778900146
# Time taken to calculate max flow boykov: 2.908320903778076
# Time taken to calculate max flow: 0.16352415084838867 flow: 24439
# Time taken to calculate max flow and min cut: 0.7961578369140625
# edges that cross the partition: 12452352
# boundary vertices: 25968
# Time taken to calculate seam: 0.17288827896118164
# Time taken to convert boundary vertices to array: 0.10252976417541504
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 75.74449515342712
# Time taken to add edges to graph: 132.33254981040955
# Time taken to add source and sink nodes: 1.4469869136810303
# Time taken to create graph 0: 210.48729586601257
# Time taken to calculate max flow boykov: 29.895339012145996
# Time taken to calculate max flow: 0.6455521583557129 flow: 92941
# Time taken to calculate max flow and min cut: 13.736961841583252
# edges that cross the partition: 100140032
# boundary vertices: 104400
# Time taken to calculate seam: 1.3928091526031494
# Time taken to convert boundary vertices to array: 0.4461848735809326
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.13322710990905762
# Time taken to add edges to graph: 0.25501322746276855
# Time taken to add source and sink nodes: 0.021988868713378906
# Time taken to create graph 3: 0.41338396072387695
# Time taken to calculate max flow boykov: 0.1134037971496582
# Time taken to calculate max flow: 0.012057065963745117 flow: 3013
# Time taken to calculate max flow and min cut: 0.008341789245605469
# edges that cross the partition: 188544
# boundary vertices: 1741
# Time taken to calculate seam: 0.003813028335571289
# Time taken to convert boundary vertices to array: 0.006769895553588867
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.11332106590271
# Time taken to add edges to graph: 1.993360996246338
# Time taken to add source and sink nodes: 0.08628487586975098
# Time taken to create graph 2: 3.2092320919036865
# Time taken to calculate max flow boykov: 0.2525522708892822
# Time taken to calculate max flow: 0.04273486137390137 flow: 9172
# Time taken to calculate max flow and min cut: 0.06664919853210449
# edges that cross the partition: 1540352
# boundary vertices: 6958
# Time taken to calculate seam: 0.019477128982543945
# Time taken to convert boundary vertices to array: 0.02538919448852539
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 9.299884796142578
# Time taken to add edges to graph: 15.98703670501709
# Time taken to add source and sink nodes: 0.3426029682159424
# Time taken to create graph 1: 25.749215841293335
# Time taken to calculate max flow boykov: 2.321237087249756
# Time taken to calculate max flow: 0.16218185424804688 flow: 32413
# Time taken to calculate max flow and min cut: 0.7029430866241455
# edges that cross the partition: 12452352
# boundary vertices: 27954
# Time taken to calculate seam: 0.1598968505859375
# Time taken to convert boundary vertices to array: 0.10430788993835449
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 77.24652814865112
# Time taken to add edges to graph: 132.7433021068573
# Time taken to add source and sink nodes: 1.4869742393493652
# Time taken to create graph 0: 212.50167965888977
# Time taken to calculate max flow boykov: 24.259347915649414
# Time taken to calculate max flow: 0.6489951610565186 flow: 119518
# Time taken to calculate max flow and min cut: 11.535635948181152
# edges that cross the partition: 100140032
# boundary vertices: 112218
# Time taken to calculate seam: 1.3782305717468262
# Time taken to convert boundary vertices to array: 0.4465370178222656
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.12843894958496094
# Time taken to add edges to graph: 0.23601174354553223
# Time taken to add source and sink nodes: 0.019736051559448242
# Time taken to create graph 3: 0.3864138126373291
# Time taken to calculate max flow boykov: 0.10015583038330078
# Time taken to calculate max flow: 0.011429786682128906 flow: 3121
# Time taken to calculate max flow and min cut: 0.006026029586791992
# edges that cross the partition: 188544
# boundary vertices: 1743
# Time taken to calculate seam: 0.002989053726196289
# Time taken to convert boundary vertices to array: 0.006392955780029297
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0370988845825195
# Time taken to add edges to graph: 1.8524739742279053
# Time taken to add source and sink nodes: 0.08142685890197754
# Time taken to create graph 2: 2.9874470233917236
# Time taken to calculate max flow boykov: 0.24730706214904785
# Time taken to calculate max flow: 0.04311513900756836 flow: 9406
# Time taken to calculate max flow and min cut: 0.07149696350097656
# edges that cross the partition: 1540352
# boundary vertices: 6988
# Time taken to calculate seam: 0.0216519832611084
# Time taken to convert boundary vertices to array: 0.027536869049072266
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 8.91629409790039
# Time taken to add edges to graph: 15.895677328109741
# Time taken to add source and sink nodes: 0.37871503829956055
# Time taken to create graph 1: 25.32588481903076
# Time taken to calculate max flow boykov: 2.4790830612182617
# Time taken to calculate max flow: 0.1626429557800293 flow: 33016
# Time taken to calculate max flow and min cut: 0.7201898097991943
# edges that cross the partition: 12452352
# boundary vertices: 28080
# Time taken to calculate seam: 0.16611504554748535
# Time taken to convert boundary vertices to array: 0.1077578067779541
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 76.38787794113159
# Time taken to add edges to graph: 131.19658017158508
# Time taken to add source and sink nodes: 1.4632771015167236
# Time taken to create graph 0: 209.99809575080872
# Time taken to calculate max flow boykov: 23.95541286468506
# Time taken to calculate max flow: 0.6523561477661133 flow: 121804
# Time taken to calculate max flow and min cut: 11.252470016479492
# edges that cross the partition: 100140032
# boundary vertices: 112739
# Time taken to calculate seam: 1.3504717350006104
# Time taken to convert boundary vertices to array: 0.44695615768432617
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.1273820400238037
# Time taken to add edges to graph: 0.23673391342163086
# Time taken to add source and sink nodes: 0.019850969314575195
# Time taken to create graph 3: 0.38639211654663086
# Time taken to calculate max flow boykov: 0.10545778274536133
# Time taken to calculate max flow: 0.01218104362487793 flow: 3193
# Time taken to calculate max flow and min cut: 0.006956815719604492
# edges that cross the partition: 188544
# boundary vertices: 1716
# Time taken to calculate seam: 0.003452301025390625
# Time taken to convert boundary vertices to array: 0.0066509246826171875
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0890371799468994
# Time taken to add edges to graph: 1.9278490543365479
# Time taken to add source and sink nodes: 0.08246493339538574
# Time taken to create graph 2: 3.115952968597412
# Time taken to calculate max flow boykov: 0.2567911148071289
# Time taken to calculate max flow: 0.04353499412536621 flow: 9541
# Time taken to calculate max flow and min cut: 0.06991314888000488
# edges that cross the partition: 1540352
# boundary vertices: 6785
# Time taken to calculate seam: 0.020147085189819336
# Time taken to convert boundary vertices to array: 0.025836706161499023
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 9.479689836502075
# Time taken to add edges to graph: 15.428024768829346
# Time taken to add source and sink nodes: 0.3416478633880615
# Time taken to create graph 1: 25.369471073150635
# Time taken to calculate max flow boykov: 2.4618968963623047
# Time taken to calculate max flow: 0.1604011058807373 flow: 33646
# Time taken to calculate max flow and min cut: 0.7866320610046387
# edges that cross the partition: 12452352
# boundary vertices: 27267
# Time taken to calculate seam: 0.15989398956298828
# Time taken to convert boundary vertices to array: 0.10269689559936523
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 76.61779618263245
# Time taken to add edges to graph: 128.83600783348083
# Time taken to add source and sink nodes: 1.4436700344085693
# Time taken to create graph 0: 207.85958003997803
# Time taken to calculate max flow boykov: 25.746997117996216
# Time taken to calculate max flow: 0.6404569149017334 flow: 124270
# Time taken to calculate max flow and min cut: 13.637222051620483
# edges that cross the partition: 100140032
# boundary vertices: 109462
# Time taken to calculate seam: 1.3851168155670166
# Time taken to convert boundary vertices to array: 0.44182825088500977
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.12960100173950195
# Time taken to add edges to graph: 0.23428606986999512
# Time taken to add source and sink nodes: 0.01947307586669922
# Time taken to create graph 3: 0.38600587844848633
# Time taken to calculate max flow boykov: 0.1322181224822998
# Time taken to calculate max flow: 0.011499166488647461 flow: 3319
# Time taken to calculate max flow and min cut: 0.00607609748840332
# edges that cross the partition: 188544
# boundary vertices: 1757
# Time taken to calculate seam: 0.0026710033416748047
# Time taken to convert boundary vertices to array: 0.006436824798583984
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0401718616485596
# Time taken to add edges to graph: 1.8325181007385254
# Time taken to add source and sink nodes: 0.08041715621948242
# Time taken to create graph 2: 2.970039129257202
# Time taken to calculate max flow boykov: 0.22582602500915527
# Time taken to calculate max flow: 0.04094099998474121 flow: 9730
# Time taken to calculate max flow and min cut: 0.06306982040405273
# edges that cross the partition: 1540352
# boundary vertices: 6986
# Time taken to calculate seam: 0.019767045974731445
# Time taken to convert boundary vertices to array: 0.025793075561523438
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 8.459095001220703
# Time taken to add edges to graph: 15.28783106803894
# Time taken to add source and sink nodes: 0.3520197868347168
# Time taken to create graph 1: 24.221436977386475
# Time taken to calculate max flow boykov: 2.2479612827301025
# Time taken to calculate max flow: 0.15993905067443848 flow: 33997
# Time taken to calculate max flow and min cut: 0.6819808483123779
# edges that cross the partition: 12452352
# boundary vertices: 27937
# Time taken to calculate seam: 0.16477227210998535
# Time taken to convert boundary vertices to array: 0.10286402702331543
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 75.1448380947113
# Time taken to add edges to graph: 131.21278166770935
# Time taken to add source and sink nodes: 1.454249382019043
# Time taken to create graph 0: 208.76355910301208
# Time taken to calculate max flow boykov: 24.00048589706421
# Time taken to calculate max flow: 0.6468627452850342 flow: 125224
# Time taken to calculate max flow and min cut: 11.105763912200928
# edges that cross the partition: 100140032
# boundary vertices: 112288
# Time taken to calculate seam: 1.3767380714416504
# Time taken to convert boundary vertices to array: 0.44868898391723633
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.13753390312194824
# Time taken to add edges to graph: 0.23904180526733398
# Time taken to add source and sink nodes: 0.019633769989013672
# Time taken to create graph 3: 0.39843201637268066
# Time taken to calculate max flow boykov: 0.11443829536437988
# Time taken to calculate max flow: 0.01160287857055664 flow: 3247
# Time taken to calculate max flow and min cut: 0.008360862731933594
# edges that cross the partition: 188544
# boundary vertices: 1690
# Time taken to calculate seam: 0.003464937210083008
# Time taken to convert boundary vertices to array: 0.0061969757080078125
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0724217891693115
# Time taken to add edges to graph: 1.9164988994598389
# Time taken to add source and sink nodes: 0.08158707618713379
# Time taken to create graph 2: 3.0868022441864014
# Time taken to calculate max flow boykov: 0.26888108253479004
# Time taken to calculate max flow: 0.04209113121032715 flow: 7912
# Time taken to calculate max flow and min cut: 0.06703686714172363
# edges that cross the partition: 1540352
# boundary vertices: 6499
# Time taken to calculate seam: 0.017919063568115234
# Time taken to convert boundary vertices to array: 0.024741172790527344
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 9.290945768356323
# Time taken to add edges to graph: 15.82719111442566
# Time taken to add source and sink nodes: 0.3435070514678955
# Time taken to create graph 1: 25.584003686904907
# Time taken to calculate max flow boykov: 2.764026165008545
# Time taken to calculate max flow: 0.162628173828125 flow: 26095
# Time taken to calculate max flow and min cut: 0.7918777465820312
# edges that cross the partition: 12452352
# boundary vertices: 25930
# Time taken to calculate seam: 0.17202305793762207
# Time taken to convert boundary vertices to array: 0.10135388374328613
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 76.7695860862732
# Time taken to add edges to graph: 131.10540437698364
# Time taken to add source and sink nodes: 1.454556941986084
# Time taken to create graph 0: 210.29124689102173
# Time taken to calculate max flow boykov: 30.631016731262207
# Time taken to calculate max flow: 0.669093132019043 flow: 97414
# Time taken to calculate max flow and min cut: 13.594134092330933
# edges that cross the partition: 100140032
# boundary vertices: 104066
# Time taken to calculate seam: 1.442394733428955
# Time taken to convert boundary vertices to array: 0.4346628189086914
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.12895584106445312
# Time taken to add edges to graph: 0.23749303817749023
# Time taken to add source and sink nodes: 0.020596027374267578
# Time taken to create graph 3: 0.3902111053466797
# Time taken to calculate max flow boykov: 0.10089397430419922
# Time taken to calculate max flow: 0.01165318489074707 flow: 3364
# Time taken to calculate max flow and min cut: 0.006231069564819336
# edges that cross the partition: 188544
# boundary vertices: 1713
# Time taken to calculate seam: 0.003147125244140625
# Time taken to convert boundary vertices to array: 0.0061931610107421875
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0312809944152832
# Time taken to add edges to graph: 1.811858892440796
# Time taken to add source and sink nodes: 0.08171486854553223
# Time taken to create graph 2: 2.941131114959717
# Time taken to calculate max flow boykov: 0.2440791130065918
# Time taken to calculate max flow: 0.04208040237426758 flow: 9829
# Time taken to calculate max flow and min cut: 0.06608104705810547
# edges that cross the partition: 1540352
# boundary vertices: 6740
# Time taken to calculate seam: 0.017218828201293945
# Time taken to convert boundary vertices to array: 0.025668859481811523
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 8.524862289428711
# Time taken to add edges to graph: 15.499622821807861
# Time taken to add source and sink nodes: 0.3416011333465576
# Time taken to create graph 1: 24.488598108291626
# Time taken to calculate max flow boykov: 2.5765130519866943
# Time taken to calculate max flow: 0.16299104690551758 flow: 34708
# Time taken to calculate max flow and min cut: 0.7641263008117676
# edges that cross the partition: 12452352
# boundary vertices: 27039
# Time taken to calculate seam: 0.16357207298278809
# Time taken to convert boundary vertices to array: 0.10039615631103516
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 75.54568696022034
# Time taken to add edges to graph: 131.57917380332947
# Time taken to add source and sink nodes: 1.4408848285675049
# Time taken to create graph 0: 209.514545917511
# Time taken to calculate max flow boykov: 26.2094087600708
# Time taken to calculate max flow: 0.6622738838195801 flow: 127699
# Time taken to calculate max flow and min cut: 13.649084091186523
# edges that cross the partition: 100140032
# boundary vertices: 108569
# Time taken to calculate seam: 1.4066920280456543
# Time taken to convert boundary vertices to array: 0.44507503509521484
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.13167810440063477
# Time taken to add edges to graph: 0.24427390098571777
# Time taken to add source and sink nodes: 0.02051711082458496
# Time taken to create graph 3: 0.39958810806274414
# Time taken to calculate max flow boykov: 0.12156105041503906
# Time taken to calculate max flow: 0.011464834213256836 flow: 3373
# Time taken to calculate max flow and min cut: 0.006270885467529297
# edges that cross the partition: 188544
# boundary vertices: 1623
# Time taken to calculate seam: 0.0029540061950683594
# Time taken to convert boundary vertices to array: 0.00616908073425293
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0655207633972168
# Time taken to add edges to graph: 1.931501865386963
# Time taken to add source and sink nodes: 0.08834695816040039
# Time taken to create graph 2: 3.103515863418579
# Time taken to calculate max flow boykov: 0.36752796173095703
# Time taken to calculate max flow: 0.04316306114196777 flow: 11035
# Time taken to calculate max flow and min cut: 0.047246694564819336
# edges that cross the partition: 1540352
# boundary vertices: 6394
# Time taken to calculate seam: 0.018617868423461914
# Time taken to convert boundary vertices to array: 0.0254361629486084
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 9.18162989616394
# Time taken to add edges to graph: 16.15755796432495
# Time taken to add source and sink nodes: 0.34465789794921875
# Time taken to create graph 1: 25.808223009109497
# Time taken to calculate max flow boykov: 3.8418211936950684
# Time taken to calculate max flow: 0.16526198387145996 flow: 39694
# Time taken to calculate max flow and min cut: 0.48169708251953125
# edges that cross the partition: 12452352
# boundary vertices: 25385
# Time taken to calculate seam: 0.1580369472503662
# Time taken to convert boundary vertices to array: 0.10399913787841797
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 77.54252886772156
# Time taken to add edges to graph: 130.43836116790771
# Time taken to add source and sink nodes: 1.47987699508667
# Time taken to create graph 0: 210.4362769126892
# Time taken to calculate max flow boykov: 40.10828185081482
# Time taken to calculate max flow: 0.6408309936523438 flow: 149371
# Time taken to calculate max flow and min cut: 7.843703269958496
# edges that cross the partition: 100140032
# boundary vertices: 101075
# Time taken to calculate seam: 1.3737342357635498
# Time taken to convert boundary vertices to array: 0.43497180938720703
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.13251805305480957
# Time taken to add edges to graph: 0.2418360710144043
# Time taken to add source and sink nodes: 0.020148038864135742
# Time taken to create graph 3: 0.3979799747467041
# Time taken to calculate max flow boykov: 0.12433195114135742
# Time taken to calculate max flow: 0.011902809143066406 flow: 3436
# Time taken to calculate max flow and min cut: 0.007476806640625
# edges that cross the partition: 188544
# boundary vertices: 1717
# Time taken to calculate seam: 0.0030469894409179688
# Time taken to convert boundary vertices to array: 0.0064640045166015625
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0505099296569824
# Time taken to add edges to graph: 1.8468050956726074
# Time taken to add source and sink nodes: 0.08274507522583008
# Time taken to create graph 2: 2.9963409900665283
# Time taken to calculate max flow boykov: 0.23505187034606934
# Time taken to calculate max flow: 0.04166698455810547 flow: 10144
# Time taken to calculate max flow and min cut: 0.0662379264831543
# edges that cross the partition: 1540352
# boundary vertices: 6764
# Time taken to calculate seam: 0.01647496223449707
# Time taken to convert boundary vertices to array: 0.025213956832885742
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 8.49107575416565
# Time taken to add edges to graph: 15.55080509185791
# Time taken to add source and sink nodes: 0.3425309658050537
# Time taken to create graph 1: 24.505640029907227
# Time taken to calculate max flow boykov: 2.5067739486694336
# Time taken to calculate max flow: 0.163862943649292 flow: 35923
# Time taken to calculate max flow and min cut: 0.7601561546325684
# edges that cross the partition: 12452352
# boundary vertices: 27055
# Time taken to calculate seam: 0.15570902824401855
# Time taken to convert boundary vertices to array: 0.10277915000915527
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 75.32386088371277
# Time taken to add edges to graph: 131.1906077861786
# Time taken to add source and sink nodes: 1.494560956954956
# Time taken to create graph 0: 208.9887180328369
# Time taken to calculate max flow boykov: 25.661647081375122
# Time taken to calculate max flow: 0.6719338893890381 flow: 131992
# Time taken to calculate max flow and min cut: 13.70551085472107
# edges that cross the partition: 100140032
# boundary vertices: 108580
# Time taken to calculate seam: 1.349240779876709
# Time taken to convert boundary vertices to array: 0.4466722011566162
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.12788081169128418
# Time taken to add edges to graph: 0.23868608474731445
# Time taken to add source and sink nodes: 0.019405841827392578
# Time taken to create graph 3: 0.3882298469543457
# Time taken to calculate max flow boykov: 0.11010289192199707
# Time taken to calculate max flow: 0.011850118637084961 flow: 3553
# Time taken to calculate max flow and min cut: 0.0051441192626953125
# edges that cross the partition: 188544
# boundary vertices: 1633
# Time taken to calculate seam: 0.003034830093383789
# Time taken to convert boundary vertices to array: 0.006216764450073242
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0324809551239014
# Time taken to add edges to graph: 1.8192930221557617
# Time taken to add source and sink nodes: 0.08140110969543457
# Time taken to create graph 2: 2.9499220848083496
# Time taken to calculate max flow boykov: 0.3324141502380371
# Time taken to calculate max flow: 0.042285919189453125 flow: 11593
# Time taken to calculate max flow and min cut: 0.044493675231933594
# edges that cross the partition: 1540352
# boundary vertices: 6418
# Time taken to calculate seam: 0.01779794692993164
# Time taken to convert boundary vertices to array: 0.024967193603515625
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 9.317701816558838
# Time taken to add edges to graph: 15.679011106491089
# Time taken to add source and sink nodes: 0.34638190269470215
# Time taken to create graph 1: 25.465219020843506
# Time taken to calculate max flow boykov: 3.935637950897217
# Time taken to calculate max flow: 0.16414713859558105 flow: 41116
# Time taken to calculate max flow and min cut: 0.48960018157958984
# edges that cross the partition: 12452352
# boundary vertices: 25431
# Time taken to calculate seam: 0.1599879264831543
# Time taken to convert boundary vertices to array: 0.10042500495910645
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 76.74780917167664
# Time taken to add edges to graph: 131.77085900306702
# Time taken to add source and sink nodes: 1.460413932800293
# Time taken to create graph 0: 210.96987295150757
# Time taken to calculate max flow boykov: 41.41862607002258
# Time taken to calculate max flow: 0.6405940055847168 flow: 152944
# Time taken to calculate max flow and min cut: 7.65463399887085
# edges that cross the partition: 100140032
# boundary vertices: 101177
# Time taken to calculate seam: 1.457524061203003
# Time taken to convert boundary vertices to array: 0.4309999942779541
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.1310281753540039
# Time taken to add edges to graph: 0.23669815063476562
# Time taken to add source and sink nodes: 0.01960587501525879
# Time taken to create graph 3: 0.38976001739501953
# Time taken to calculate max flow boykov: 0.1233069896697998
# Time taken to calculate max flow: 0.011595964431762695 flow: 3643
# Time taken to calculate max flow and min cut: 0.006100893020629883
# edges that cross the partition: 188544
# boundary vertices: 1758
# Time taken to calculate seam: 0.0026290416717529297
# Time taken to convert boundary vertices to array: 0.006231069564819336
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0416650772094727
# Time taken to add edges to graph: 1.841609239578247
# Time taken to add source and sink nodes: 0.08493304252624512
# Time taken to create graph 2: 2.9847660064697266
# Time taken to calculate max flow boykov: 0.2829749584197998
# Time taken to calculate max flow: 0.04423999786376953 flow: 10999
# Time taken to calculate max flow and min cut: 0.07139921188354492
# edges that cross the partition: 1540352
# boundary vertices: 6994
# Time taken to calculate seam: 0.016869068145751953
# Time taken to convert boundary vertices to array: 0.025380849838256836
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 9.166805982589722
# Time taken to add edges to graph: 15.516634702682495
# Time taken to add source and sink nodes: 0.3436579704284668
# Time taken to create graph 1: 25.148615837097168
# Time taken to calculate max flow boykov: 2.766141891479492
# Time taken to calculate max flow: 0.1632688045501709 flow: 37732
# Time taken to calculate max flow and min cut: 0.7860631942749023
# edges that cross the partition: 12452352
# boundary vertices: 28095
# Time taken to calculate seam: 0.1646900177001953
# Time taken to convert boundary vertices to array: 0.10093903541564941
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 75.44583702087402
# Time taken to add edges to graph: 130.32727479934692
# Time taken to add source and sink nodes: 1.4568710327148438
# Time taken to create graph 0: 208.18309688568115
# Time taken to calculate max flow boykov: 27.2468159198761
# Time taken to calculate max flow: 0.6387770175933838 flow: 137104
# Time taken to calculate max flow and min cut: 13.262907028198242
# edges that cross the partition: 100140032
# boundary vertices: 112743
# Time taken to calculate seam: 1.3771460056304932
# Time taken to convert boundary vertices to array: 0.46256113052368164
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.12874102592468262
# Time taken to add edges to graph: 0.23493385314941406
# Time taken to add source and sink nodes: 0.020389080047607422
# Time taken to create graph 3: 0.3864922523498535
# Time taken to calculate max flow boykov: 0.13242697715759277
# Time taken to calculate max flow: 0.011560916900634766 flow: 3679
# Time taken to calculate max flow and min cut: 0.005578041076660156
# edges that cross the partition: 188544
# boundary vertices: 1720
# Time taken to calculate seam: 0.0027289390563964844
# Time taken to convert boundary vertices to array: 0.006227254867553711
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0326480865478516
# Time taken to add edges to graph: 1.8158390522003174
# Time taken to add source and sink nodes: 0.08117818832397461
# Time taken to create graph 2: 2.945664882659912
# Time taken to calculate max flow boykov: 0.294079065322876
# Time taken to calculate max flow: 0.04220294952392578 flow: 11026
# Time taken to calculate max flow and min cut: 0.04815101623535156
# edges that cross the partition: 1540352
# boundary vertices: 6815
# Time taken to calculate seam: 0.017091989517211914
# Time taken to convert boundary vertices to array: 0.026007890701293945
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 9.087382793426514
# Time taken to add edges to graph: 15.298586130142212
# Time taken to add source and sink nodes: 0.34531188011169434
# Time taken to create graph 1: 24.854552030563354
# Time taken to calculate max flow boykov: 3.269960880279541
# Time taken to calculate max flow: 0.1601698398590088 flow: 38911
# Time taken to calculate max flow and min cut: 0.4929850101470947
# edges that cross the partition: 12452352
# boundary vertices: 27112
# Time taken to calculate seam: 0.15500307083129883
# Time taken to convert boundary vertices to array: 0.10360097885131836
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 77.49089813232422
# Time taken to add edges to graph: 131.61011004447937
# Time taken to add source and sink nodes: 1.4467010498046875
# Time taken to create graph 0: 211.50550603866577
# Time taken to calculate max flow boykov: 36.265501976013184
# Time taken to calculate max flow: 0.6397707462310791 flow: 145987
# Time taken to calculate max flow and min cut: 7.5653510093688965
# edges that cross the partition: 100140032
# boundary vertices: 108064
# Time taken to calculate seam: 1.4108819961547852
# Time taken to convert boundary vertices to array: 0.4437680244445801
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.1296980381011963
# Time taken to add edges to graph: 0.23742175102233887
# Time taken to add source and sink nodes: 0.019328832626342773
# Time taken to create graph 3: 0.3893849849700928
# Time taken to calculate max flow boykov: 0.1441507339477539
# Time taken to calculate max flow: 0.01165318489074707 flow: 3751
# Time taken to calculate max flow and min cut: 0.0069408416748046875
# edges that cross the partition: 188544
# boundary vertices: 1745
# Time taken to calculate seam: 0.0028600692749023438
# Time taken to convert boundary vertices to array: 0.006412982940673828
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0328099727630615
# Time taken to add edges to graph: 1.8326070308685303
# Time taken to add source and sink nodes: 0.08114814758300781
# Time taken to create graph 2: 2.96356201171875
# Time taken to calculate max flow boykov: 0.2578890323638916
# Time taken to calculate max flow: 0.041284799575805664 flow: 10927
# Time taken to calculate max flow and min cut: 0.06874990463256836
# edges that cross the partition: 1540352
# boundary vertices: 6925
# Time taken to calculate seam: 0.0165860652923584
# Time taken to convert boundary vertices to array: 0.025480985641479492
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 8.679814100265503
# Time taken to add edges to graph: 15.50778603553772
# Time taken to add source and sink nodes: 0.3415710926055908
# Time taken to create graph 1: 24.653889656066895
# Time taken to calculate max flow boykov: 2.8370158672332764
# Time taken to calculate max flow: 0.16233205795288086 flow: 36409
# Time taken to calculate max flow and min cut: 0.7864899635314941
# edges that cross the partition: 12452352
# boundary vertices: 27811
# Time taken to calculate seam: 0.158951997756958
# Time taken to convert boundary vertices to array: 0.10349583625793457
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 75.68405389785767
# Time taken to add edges to graph: 131.73594498634338
# Time taken to add source and sink nodes: 1.4899108409881592
# Time taken to create graph 0: 209.88495922088623
# Time taken to calculate max flow boykov: 30.096303701400757
# Time taken to calculate max flow: 0.6564040184020996 flow: 131560
# Time taken to calculate max flow and min cut: 14.35008692741394
# edges that cross the partition: 100140032
# boundary vertices: 111771
# Time taken to calculate seam: 1.350848913192749
# Time taken to convert boundary vertices to array: 0.44436001777648926
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.13228297233581543
# Time taken to add edges to graph: 0.23406696319580078
# Time taken to add source and sink nodes: 0.020903825759887695
# Time taken to create graph 3: 0.3895578384399414
# Time taken to calculate max flow boykov: 0.16308808326721191
# Time taken to calculate max flow: 0.012070894241333008 flow: 3751
# Time taken to calculate max flow and min cut: 0.008125066757202148
# edges that cross the partition: 188544
# boundary vertices: 1730
# Time taken to calculate seam: 0.00415802001953125
# Time taken to convert boundary vertices to array: 0.0065991878509521484
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0903983116149902
# Time taken to add edges to graph: 1.8996360301971436
# Time taken to add source and sink nodes: 0.0877680778503418
# Time taken to create graph 2: 3.0942111015319824
# Time taken to calculate max flow boykov: 0.298900842666626
# Time taken to calculate max flow: 0.04294705390930176 flow: 10558
# Time taken to calculate max flow and min cut: 0.07284927368164062
# edges that cross the partition: 1540352
# boundary vertices: 6862
# Time taken to calculate seam: 0.017548084259033203
# Time taken to convert boundary vertices to array: 0.02686905860900879
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 9.275625944137573
# Time taken to add edges to graph: 16.28113579750061
# Time taken to add source and sink nodes: 0.3538520336151123
# Time taken to create graph 1: 26.034953355789185
# Time taken to calculate max flow boykov: 3.064054012298584
# Time taken to calculate max flow: 0.16230177879333496 flow: 36823
# Time taken to calculate max flow and min cut: 0.8213198184967041
# edges that cross the partition: 12452352
# boundary vertices: 27531
# Time taken to calculate seam: 0.16518187522888184
# Time taken to convert boundary vertices to array: 0.10689592361450195
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 77.17695689201355
# Time taken to add edges to graph: 131.25955510139465
# Time taken to add source and sink nodes: 1.456118106842041
# Time taken to create graph 0: 210.84969902038574
# Time taken to calculate max flow boykov: 31.068079948425293
# Time taken to calculate max flow: 0.643420934677124 flow: 133153
# Time taken to calculate max flow and min cut: 14.420229196548462
# edges that cross the partition: 100140032
# boundary vertices: 110548
# Time taken to calculate seam: 1.4375519752502441
# Time taken to convert boundary vertices to array: 0.44190192222595215
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.1315598487854004
# Time taken to add edges to graph: 0.23553824424743652
# Time taken to add source and sink nodes: 0.02016592025756836
# Time taken to create graph 3: 0.3899059295654297
# Time taken to calculate max flow boykov: 0.10008502006530762
# Time taken to calculate max flow: 0.011534929275512695 flow: 3760
# Time taken to calculate max flow and min cut: 0.005546092987060547
# edges that cross the partition: 188544
# boundary vertices: 1781
# Time taken to calculate seam: 0.0028200149536132812
# Time taken to convert boundary vertices to array: 0.0062961578369140625
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0385589599609375
# Time taken to add edges to graph: 1.8545238971710205
# Time taken to add source and sink nodes: 0.08063483238220215
# Time taken to create graph 2: 2.9889211654663086
# Time taken to calculate max flow boykov: 0.24153804779052734
# Time taken to calculate max flow: 0.0429990291595459 flow: 10108
# Time taken to calculate max flow and min cut: 0.06536126136779785
# edges that cross the partition: 1540352
# boundary vertices: 6987
# Time taken to calculate seam: 0.02077007293701172
# Time taken to convert boundary vertices to array: 0.025447845458984375
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 8.715034008026123
# Time taken to add edges to graph: 15.538635969161987
# Time taken to add source and sink nodes: 0.3455376625061035
# Time taken to create graph 1: 24.720983743667603
# Time taken to calculate max flow boykov: 2.285168170928955
# Time taken to calculate max flow: 0.16057109832763672 flow: 34411
# Time taken to calculate max flow and min cut: 0.695814847946167
# edges that cross the partition: 12452352
# boundary vertices: 27987
# Time taken to calculate seam: 0.1685469150543213
# Time taken to convert boundary vertices to array: 0.1035468578338623
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 75.19834899902344
# Time taken to add edges to graph: 131.33599209785461
# Time taken to add source and sink nodes: 1.4515249729156494
# Time taken to create graph 0: 208.94607710838318
# Time taken to calculate max flow boykov: 22.77070116996765
# Time taken to calculate max flow: 0.6434268951416016 flow: 125656
# Time taken to calculate max flow and min cut: 10.547845125198364
# edges that cross the partition: 100140032
# boundary vertices: 112323
# Time taken to calculate seam: 1.3735101222991943
# Time taken to convert boundary vertices to array: 0.44818902015686035
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.1292591094970703
# Time taken to add edges to graph: 0.23683619499206543
# Time taken to add source and sink nodes: 0.020878076553344727
# Time taken to create graph 3: 0.38976120948791504
# Time taken to calculate max flow boykov: 0.11259317398071289
# Time taken to calculate max flow: 0.011655807495117188 flow: 3814
# Time taken to calculate max flow and min cut: 0.004992961883544922
# edges that cross the partition: 188544
# boundary vertices: 1639
# Time taken to calculate seam: 0.0029349327087402344
# Time taken to convert boundary vertices to array: 0.006294965744018555
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0870769023895264
# Time taken to add edges to graph: 1.8275070190429688
# Time taken to add source and sink nodes: 0.0825498104095459
# Time taken to create graph 2: 3.0139999389648438
# Time taken to calculate max flow boykov: 0.3367030620574951
# Time taken to calculate max flow: 0.04088997840881348 flow: 12034
# Time taken to calculate max flow and min cut: 0.04690909385681152
# edges that cross the partition: 1540352
# boundary vertices: 6409
# Time taken to calculate seam: 0.016743183135986328
# Time taken to convert boundary vertices to array: 0.025073766708374023
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 9.343644142150879
# Time taken to add edges to graph: 15.416802883148193
# Time taken to add source and sink nodes: 0.34310007095336914
# Time taken to create graph 1: 25.22465682029724
# Time taken to calculate max flow boykov: 3.709294080734253
# Time taken to calculate max flow: 0.16131091117858887 flow: 42214
# Time taken to calculate max flow and min cut: 0.4841148853302002
# edges that cross the partition: 12452352
# boundary vertices: 25545
# Time taken to calculate seam: 0.15577983856201172
# Time taken to convert boundary vertices to array: 0.10251688957214355
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 76.24492001533508
# Time taken to add edges to graph: 129.8761420249939
# Time taken to add source and sink nodes: 1.4548990726470947
# Time taken to create graph 0: 208.53873205184937
# Time taken to calculate max flow boykov: 40.66178798675537
# Time taken to calculate max flow: 0.642575740814209 flow: 157651
# Time taken to calculate max flow and min cut: 7.884862899780273
# edges that cross the partition: 100140032
# boundary vertices: 101966
# Time taken to calculate seam: 1.3737568855285645
# Time taken to convert boundary vertices to array: 0.4419901371002197
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.13149809837341309
# Time taken to add edges to graph: 0.23385405540466309
# Time taken to add source and sink nodes: 0.020277023315429688
# Time taken to create graph 3: 0.3882267475128174
# Time taken to calculate max flow boykov: 0.09721970558166504
# Time taken to calculate max flow: 0.011621952056884766 flow: 3841
# Time taken to calculate max flow and min cut: 0.005758047103881836
# edges that cross the partition: 188544
# boundary vertices: 1774
# Time taken to calculate seam: 0.0032379627227783203
# Time taken to convert boundary vertices to array: 0.006395816802978516
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0433731079101562
# Time taken to add edges to graph: 1.8545351028442383
# Time taken to add source and sink nodes: 0.0833427906036377
# ...
# Time taken to add vertices to coord_to_vertex: 8.537842988967896
# Time taken to add edges to graph: 15.025596857070923
# Time taken to add source and sink nodes: 0.32675814628601074
# Time taken to create graph 1: 24.006577014923096
# Time taken to calculate max flow boykov: 2.484621047973633
# Time taken to calculate max flow: 0.1537611484527588 flow: 67603
# Time taken to calculate max flow and min cut: 0.6350700855255127
# edges that cross the partition: 12452352
# boundary vertices: 28695
# Time taken to calculate seam: 0.15505671501159668
# Time taken to convert boundary vertices to array: 0.10195684432983398
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 72.90763711929321
# Time taken to add edges to graph: 125.59616589546204
# Time taken to add source and sink nodes: 1.4371910095214844
# Time taken to create graph 0: 200.88389086723328
# Time taken to calculate max flow boykov: 25.56433892250061
# Time taken to calculate max flow: 0.6199519634246826 flow: 238228
# Time taken to calculate max flow and min cut: 9.874616861343384
# edges that cross the partition: 100140032
# boundary vertices: 114403
# Time taken to calculate seam: 1.3875267505645752
# Time taken to convert boundary vertices to array: 0.42708897590637207
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.12695598602294922
# Time taken to add edges to graph: 0.22403478622436523
# Time taken to add source and sink nodes: 0.019396066665649414
# Time taken to create graph 3: 0.37256908416748047
# Time taken to calculate max flow boykov: 0.05707097053527832
# Time taken to calculate max flow: 0.01129293441772461 flow: 6829
# Time taken to calculate max flow and min cut: 0.004734992980957031
# edges that cross the partition: 188544
# boundary vertices: 1872
# Time taken to calculate seam: 0.0025968551635742188
# Time taken to convert boundary vertices to array: 0.0062007904052734375
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0158228874206543
# Time taken to add edges to graph: 1.8018009662628174
# Time taken to add source and sink nodes: 0.0780947208404541
# Time taken to create graph 2: 2.9121270179748535
# Time taken to calculate max flow boykov: 0.2669820785522461
# Time taken to calculate max flow: 0.03974294662475586 flow: 20179
# Time taken to calculate max flow and min cut: 0.05907797813415527
# edges that cross the partition: 1540352
# boundary vertices: 7249
# Time taken to calculate seam: 0.01637101173400879
# Time taken to convert boundary vertices to array: 0.024714946746826172
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 8.898035764694214
# Time taken to add edges to graph: 14.934191226959229
# Time taken to add source and sink nodes: 0.3264760971069336
# Time taken to create graph 1: 24.273452043533325
# Time taken to calculate max flow boykov: 2.7689452171325684
# Time taken to calculate max flow: 0.15474987030029297 flow: 65407
# Time taken to calculate max flow and min cut: 0.6075131893157959
# edges that cross the partition: 12452352
# boundary vertices: 28478
# Time taken to calculate seam: 0.1578819751739502
# Time taken to convert boundary vertices to array: 0.0998687744140625
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 74.10650420188904
# Time taken to add edges to graph: 125.55352783203125
# Time taken to add source and sink nodes: 1.4602420330047607
# Time taken to create graph 0: 202.09461903572083
# Time taken to calculate max flow boykov: 29.884275913238525
# Time taken to calculate max flow: 0.6336140632629395 flow: 228472
# Time taken to calculate max flow and min cut: 9.755622863769531
# edges that cross the partition: 100140032
# boundary vertices: 113635
# Time taken to calculate seam: 1.3397190570831299
# Time taken to convert boundary vertices to array: 0.44605088233947754
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.12951183319091797
# Time taken to add edges to graph: 0.22795963287353516
# Time taken to add source and sink nodes: 0.018906116485595703
# Time taken to create graph 3: 0.3786470890045166
# Time taken to calculate max flow boykov: 0.054947853088378906
# Time taken to calculate max flow: 0.011208772659301758 flow: 6802
# Time taken to calculate max flow and min cut: 0.005036115646362305
# edges that cross the partition: 188544
# boundary vertices: 1837
# Time taken to calculate seam: 0.002744913101196289
# Time taken to convert boundary vertices to array: 0.006424903869628906
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.037580966949463
# Time taken to add edges to graph: 1.8355939388275146
# Time taken to add source and sink nodes: 0.08142805099487305
# Time taken to create graph 2: 2.9714131355285645
# Time taken to calculate max flow boykov: 0.2487788200378418
# Time taken to calculate max flow: 0.03902912139892578 flow: 20242
# Time taken to calculate max flow and min cut: 0.0653533935546875
# edges that cross the partition: 1540352
# boundary vertices: 7136
# Time taken to calculate seam: 0.016537189483642578
# Time taken to convert boundary vertices to array: 0.025683879852294922
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 8.424865007400513
# Time taken to add edges to graph: 15.174528121948242
# Time taken to add source and sink nodes: 0.3332250118255615
# Time taken to create graph 1: 24.050925970077515
# Time taken to calculate max flow boykov: 2.519868850708008
# Time taken to calculate max flow: 0.1557178497314453 flow: 66316
# Time taken to calculate max flow and min cut: 0.7022049427032471
# edges that cross the partition: 12452352
# boundary vertices: 28368
# Time taken to calculate seam: 0.1537179946899414
# Time taken to convert boundary vertices to array: 0.10191106796264648
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 74.2148768901825
# Time taken to add edges to graph: 128.0212287902832
# Time taken to add source and sink nodes: 1.400320053100586
# Time taken to create graph 0: 204.58436393737793
# Time taken to calculate max flow boykov: 26.20279598236084
# Time taken to calculate max flow: 0.6186532974243164 flow: 232378
# Time taken to calculate max flow and min cut: 10.466138124465942
# edges that cross the partition: 100140032
# boundary vertices: 113722
# Time taken to calculate seam: 1.3378849029541016
# Time taken to convert boundary vertices to array: 0.44432687759399414
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.1279158592224121
# Time taken to add edges to graph: 0.2275090217590332
# Time taken to add source and sink nodes: 0.018229007720947266
# Time taken to create graph 3: 0.3759291172027588
# Time taken to calculate max flow boykov: 0.06906604766845703
# Time taken to calculate max flow: 0.01118326187133789 flow: 6964
# Time taken to calculate max flow and min cut: 0.004876136779785156
# edges that cross the partition: 188544
# boundary vertices: 1864
# Time taken to calculate seam: 0.0026209354400634766
# Time taken to convert boundary vertices to array: 0.006371021270751953
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0338449478149414
# Time taken to add edges to graph: 1.8297040462493896
# Time taken to add source and sink nodes: 0.07770419120788574
# Time taken to create graph 2: 2.9585390090942383
# Time taken to calculate max flow boykov: 0.254133939743042
# Time taken to calculate max flow: 0.039105892181396484 flow: 21187
# Time taken to calculate max flow and min cut: 0.06789898872375488
# edges that cross the partition: 1540352
# boundary vertices: 7208
# Time taken to calculate seam: 0.017271757125854492
# Time taken to convert boundary vertices to array: 0.025543928146362305
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 8.85873007774353
# Time taken to add edges to graph: 15.244925022125244
# Time taken to add source and sink nodes: 0.33087992668151855
# Time taken to create graph 1: 24.555569887161255
# Time taken to calculate max flow boykov: 2.4284489154815674
# Time taken to calculate max flow: 0.15396809577941895 flow: 69340
# Time taken to calculate max flow and min cut: 0.7071671485900879
# edges that cross the partition: 12452352
# boundary vertices: 28550
# Time taken to calculate seam: 0.1527087688446045
# Time taken to convert boundary vertices to array: 0.10219192504882812
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 74.96872591972351
# Time taken to add edges to graph: 127.57636380195618
# Time taken to add source and sink nodes: 1.3806471824645996
# Time taken to create graph 0: 204.85911774635315
# Time taken to calculate max flow boykov: 24.964797973632812
# Time taken to calculate max flow: 0.6214568614959717 flow: 239740
# Time taken to calculate max flow and min cut: 10.879579782485962
# edges that cross the partition: 100140032
# boundary vertices: 113902
# Time taken to calculate seam: 1.3331429958343506
# Time taken to convert boundary vertices to array: 0.43880510330200195
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.12775826454162598
# Time taken to add edges to graph: 0.2263011932373047
# Time taken to add source and sink nodes: 0.020062923431396484
# Time taken to create graph 3: 0.3763089179992676
# Time taken to calculate max flow boykov: 0.05557084083557129
# Time taken to calculate max flow: 0.011366844177246094 flow: 7054
# Time taken to calculate max flow and min cut: 0.00477290153503418
# edges that cross the partition: 188544
# boundary vertices: 1738
# Time taken to calculate seam: 0.003013134002685547
# Time taken to convert boundary vertices to array: 0.006244182586669922
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.017880916595459
# Time taken to add edges to graph: 1.7903368473052979
# Time taken to add source and sink nodes: 0.07888197898864746
# Time taken to create graph 2: 2.9037656784057617
# Time taken to calculate max flow boykov: 0.31790995597839355
# Time taken to calculate max flow: 0.03903627395629883 flow: 20620
# Time taken to calculate max flow and min cut: 0.05306196212768555
# edges that cross the partition: 1540352
# boundary vertices: 6977
# Time taken to calculate seam: 0.01681208610534668
# Time taken to convert boundary vertices to array: 0.024970054626464844
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 8.31478476524353
# Time taken to add edges to graph: 15.115535020828247
# Time taken to add source and sink nodes: 0.32671308517456055
# Time taken to create graph 1: 23.874728202819824
# Time taken to calculate max flow boykov: 3.475980043411255
# Time taken to calculate max flow: 0.15800714492797852 flow: 64219
# Time taken to calculate max flow and min cut: 0.535923957824707
# edges that cross the partition: 12452352
# boundary vertices: 27627
# Time taken to calculate seam: 0.15472006797790527
# Time taken to convert boundary vertices to array: 0.10129427909851074
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 72.85430788993835
# Time taken to add edges to graph: 126.30565094947815
# Time taken to add source and sink nodes: 1.3953649997711182
# Time taken to create graph 0: 201.50371503829956
# Time taken to calculate max flow boykov: 37.91382193565369
# Time taken to calculate max flow: 0.6234738826751709 flow: 225484
# Time taken to calculate max flow and min cut: 8.73623514175415
# edges that cross the partition: 100140032
# boundary vertices: 109981
# Time taken to calculate seam: 1.3437912464141846
# Time taken to convert boundary vertices to array: 0.4331328868865967
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.12754392623901367
# Time taken to add edges to graph: 0.22365522384643555
# Time taken to add source and sink nodes: 0.01975870132446289
# Time taken to create graph 3: 0.37312793731689453
# Time taken to calculate max flow boykov: 0.04322481155395508
# Time taken to calculate max flow: 0.011324882507324219 flow: 7072
# Time taken to calculate max flow and min cut: 0.0048902034759521484
# edges that cross the partition: 188544
# boundary vertices: 1883
# Time taken to calculate seam: 0.002744913101196289
# Time taken to convert boundary vertices to array: 0.0062520503997802734
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0652718544006348
# Time taken to add edges to graph: 1.781376838684082
# Time taken to add source and sink nodes: 0.07956099510192871
# Time taken to create graph 2: 2.9437289237976074
# Time taken to calculate max flow boykov: 0.24801015853881836
# Time taken to calculate max flow: 0.0395660400390625 flow: 20791
# Time taken to calculate max flow and min cut: 0.06453704833984375
# edges that cross the partition: 1540352
# boundary vertices: 7253
# Time taken to calculate seam: 0.018046855926513672
# Time taken to convert boundary vertices to array: 0.02519392967224121
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 9.15105414390564
# Time taken to add edges to graph: 15.039436101913452
# Time taken to add source and sink nodes: 0.330061674118042
# Time taken to create graph 1: 24.635472059249878
# Time taken to calculate max flow boykov: 2.322974920272827
# Time taken to calculate max flow: 0.1546037197113037 flow: 67405
# Time taken to calculate max flow and min cut: 0.6634187698364258
# edges that cross the partition: 12452352
# boundary vertices: 28672
# Time taken to calculate seam: 0.16065096855163574
# Time taken to convert boundary vertices to array: 0.10191082954406738
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 74.42006707191467
# Time taken to add edges to graph: 126.31115174293518
# Time taken to add source and sink nodes: 1.3964600563049316
# Time taken to create graph 0: 203.06737208366394
# Time taken to calculate max flow boykov: 24.716443061828613
# Time taken to calculate max flow: 0.6212811470031738 flow: 234520
# Time taken to calculate max flow and min cut: 10.054673194885254
# edges that cross the partition: 100140032
# boundary vertices: 114656
# Time taken to calculate seam: 1.339141845703125
# Time taken to convert boundary vertices to array: 0.43862104415893555
# 32 32 32
# Time taken to add vertices to coord_to_vertex: 0.12752223014831543
# Time taken to add edges to graph: 0.22515201568603516
# Time taken to add source and sink nodes: 0.019273042678833008
# Time taken to create graph 3: 0.37416505813598633
# Time taken to calculate max flow boykov: 0.04487323760986328
# Time taken to calculate max flow: 0.011266946792602539 flow: 7189
# Time taken to calculate max flow and min cut: 0.005214214324951172
# edges that cross the partition: 188544
# boundary vertices: 1871
# Time taken to calculate seam: 0.002595186233520508
# Time taken to convert boundary vertices to array: 0.006239891052246094
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0296030044555664
# Time taken to add edges to graph: 1.77695894241333
# Time taken to add source and sink nodes: 0.079254150390625
# Time taken to create graph 2: 2.902894973754883
# Time taken to calculate max flow boykov: 0.21475768089294434
# Time taken to calculate max flow: 0.038702964782714844 flow: 18919
# Time taken to calculate max flow and min cut: 0.06464195251464844
# edges that cross the partition: 1540352
# boundary vertices: 7048
# Time taken to calculate seam: 0.016311168670654297
# Time taken to convert boundary vertices to array: 0.025171995162963867
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 8.352748155593872
# Time taken to add edges to graph: 15.093439102172852
# Time taken to add source and sink nodes: 0.32750582695007324
# Time taken to create graph 1: 23.8886239528656
# Time taken to calculate max flow boykov: 2.1539700031280518
# Time taken to calculate max flow: 0.1515209674835205 flow: 55435
# Time taken to calculate max flow and min cut: 0.7228999137878418
# edges that cross the partition: 12452352
# boundary vertices: 27743
# Time taken to calculate seam: 0.1491708755493164
# Time taken to convert boundary vertices to array: 0.1020820140838623
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 73.39046883583069
# Time taken to add edges to graph: 126.16164374351501
# Time taken to add source and sink nodes: 1.3910191059112549
# Time taken to create graph 0: 201.8723771572113
# Time taken to calculate max flow boykov: 22.154252767562866
# Time taken to calculate max flow: 0.6206419467926025 flow: 186118
# Time taken to calculate max flow and min cut: 10.769273281097412
# edges that cross the partition: 100140032
# boundary vertices: 110842
# Time taken to calculate seam: 1.3226289749145508
# Time taken to convert boundary vertices to array: 0.436525821685791

# %%
print(mask_array_data[0].shape, raw_array_data.shape)
# Out:
# (256, 256, 256) (256, 256, 256)

# %%
#save results
# Create output directory if it doesn't exist
output_dir = os.path.join(os.getcwd(), 'output/densified_cubes')
os.makedirs(output_dir, exist_ok=True)

# Get the current timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# Save mask_array_data[0] as NRRD with a timestamp
mask_nrrd_path = os.path.join(output_dir, f'densified_label_{timestamp}.nrrd')
nrrd.write(mask_nrrd_path, mask_array_data[0])
print(f"Saved mask_array_data[0] to {mask_nrrd_path}")

# Save raw_array_data as NRRD with a timestamp
raw_nrrd_path = os.path.join(output_dir, f'densified_data_{timestamp}.nrrd')
nrrd.write(raw_nrrd_path, raw_array_data)
print(f"Saved raw_array_data to {raw_nrrd_path}")
# Out:
# Saved mask_array_data[0] to /Users/jamesdarby/Documents/VesuviusScroll/GP/3D_sheet_carving/output/densified_cubes/densified_label_20240607_060716.nrrd
# Saved raw_array_data to /Users/jamesdarby/Documents/VesuviusScroll/GP/3D_sheet_carving/output/densified_cubes/densified_data_20240607_060716.nrrd

# %%
#plot seam ontop of mask array
res_i = 0
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(mark_boundaries_color(raw_array_data[:,slice_index,:], mask_array_data[res_i][:,slice_index,:]))
    elif axis == 2:
        plt.imshow(mark_boundaries_color(raw_array_data[:,:,slice_index], mask_array_data[res_i][:,:,slice_index]))
    else:
        plt.imshow(mark_boundaries_color(raw_array_data[slice_index,:,:], mask_array_data[res_i][slice_index,:,:]))
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=boundary_array.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
#plot boundary array, aka seam to remove
res_i = 0
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(boundary_array[:,slice_index,:])
    elif axis == 2:
        plt.imshow(boundary_array[:,:,slice_index])
    else:
        plt.imshow(boundary_array[slice_index,:,:])
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=boundary_array.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
#plot seam ontop of mask array
res_i = 0
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(mark_boundaries_color(boundary_array[:,slice_index,:], reduced_mask_data[res_i][:,slice_index,:]))
    elif axis == 2:
        plt.imshow(mark_boundaries_color(boundary_array[:,:,slice_index], reduced_mask_data[res_i][:,:,slice_index]))
    else:
        plt.imshow(mark_boundaries_color(boundary_array[slice_index,:,:], reduced_mask_data[res_i][slice_index,:,:]))
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=boundary_array.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
