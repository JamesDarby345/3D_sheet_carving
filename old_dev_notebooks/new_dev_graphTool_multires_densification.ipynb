# %%
import nrrd
import numpy as np
import os
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider
from skimage.segmentation import mark_boundaries
import cv2
from scipy import ndimage as ndi
from helper import *
import graph_tool.all as gt
import plotly.graph_objects as go
import time
from datetime import datetime


current_directory = os.getcwd()
label_path = f"{current_directory}/data/label/manual_2_label.nrrd"
raw_data_path = f"{current_directory}/data/raw/manual_2_raw.nrrd"

mask_data, mask_header = nrrd.read(label_path)
raw_data, raw_header = nrrd.read(raw_data_path)

# %%
#rotate the data for best cut angle and calculate reduced data representations
#NOTE: dont rotate manual label 2
# axis = 1 #0 for x, 1 for y and 2 for z
# k = 1 # number of times to rotate the array
# mask_data = np.rot90(mask_data, k, axes=(axis, (axis+1)%3))
# raw_data = np.rot90(raw_data, k, axes=(axis, (axis+1)%3))

reduced_mask_data = coarsen_image(mask_data, 3)
reduced_raw_data = coarsen_image(raw_data, 3)
#[0] is full res, each further index is 2x lower res, 256, 128, 64, 32

# %%
print(mask_data.dtype, raw_data.dtype)
print(reduced_mask_data[0].dtype, reduced_raw_data[0].dtype)
# Out:
# uint8 float32

# %%
#create reduced graph
res_index = 2
rotated_directed_graph, r_src, r_tgt, rotated_weights, x_pos, y_pos, z_pos = create_masked_directed_energy_graph_from_mask(reduced_mask_data[res_index])
# Out:
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 3.0037529468536377
# Time taken to add edges to graph: 1.9192349910736084
# Time taken to add source and sink nodes: 0.07884526252746582

# %%
def calculate_seam_iter(directed_graph, src, tgt, weights, test_size, x_pos, y_pos, z_pos):
    # Compute the residual capactiy of the edges
    stime = time.time()
    res = gt.boykov_kolmogorov_max_flow(directed_graph, src, tgt, weights) #time complexity: edges * vertices^2 * abs(min cut) 
    print("Time taken to calculate max flow boykov:", time.time()-stime)
    # sptime = time.time()
    # res = gt.push_relabel_max_flow(directed_graph, src, tgt, weights) #time complexity: vertices^3 <- scales better for our graph
    # print("Time taken to calculate max flow push relabel:", time.time()-sptime)
    stime = time.time()
    #use the residual graph to get the max flow
    flow = sum(weights[e] - res[e] for e in tgt.in_edges())
    # print("The maximum flow from source to sink is:", flow)
    print("Time taken to calculate max flow:", time.time()-stime, "flow:", flow)
    stime = time.time()
    # Determine the minimum cut partition
    part = gt.min_st_cut(directed_graph, src, weights, res)
    # print("The number of vertices in the partiton:", sum(part))
    print("Time taken to calculate max flow and min cut:", time.time()-stime)
    # Find the boundary vertices
    stime = time.time()
    boundary_vertices = find_boundary_vertices(np.array(directed_graph.get_edges()), part)
    # print("Number of boundary vertices:", len(boundary_vertices))
    print("Time taken to calculate seam:", time.time()-stime)

    shape = (test_size, test_size, test_size)

    # Convert the boundary vertices to a 3D array
    stime = time.time()
    boundary_array = boundary_vertices_to_array_masked(boundary_vertices, shape, 'x', x_pos, y_pos, z_pos)
    # print("Boundary points marked:", np.sum(boundary_array))
    print("Time taken to convert boundary vertices to array:", time.time()-stime)

    return boundary_array, flow

# %%
boundary_array, flow = calculate_seam_iter(rotated_directed_graph, r_src, r_tgt, rotated_weights, reduced_mask_data[res_index].shape[0], x_pos, y_pos, z_pos)
b_arr_up = upscale_and_dilate_3d(boundary_array, upscale_factor=4, dilation_amount=1)
print(b_arr_up.shape)
# Out:
# Time taken to calculate max flow boykov: 1.3382949829101562
# Time taken to calculate max flow: 0.041169166564941406 flow: 6184
# Time taken to calculate max flow and min cut: 0.10150313377380371
# edges that cross the partition: 1540352
# boundary vertices: 6394
# Time taken to calculate seam: 0.022275209426879883
# Time taken to convert boundary vertices to array: 0.026378870010375977
# (256, 256, 256)

# %%
# copying and masking the high res data for masked graph creation
res_index = 0
masked_array = reduced_mask_data[res_index].copy()
print(masked_array.shape, b_arr_up.shape)
masked_array[b_arr_up == 0] = -1

masked_graph, masked_src, masked_sink, masked_weights, x_pos, y_pos, z_pos = create_masked_directed_energy_graph_from_mask(masked_array)
# Out:
# (256, 256, 256) (256, 256, 256)
# 256 256 256
# /var/folders/0t/my3c3j251vl2s6y6tvgd80ph0000gn/T/ipykernel_34351/3695038853.py:5: DeprecationWarning: NumPy will stop allowing conversion of out-of-bound Python integers to integer arrays.  The conversion of -1 to uint8 will fail in the future.
# For the old behavior, usually:
#     np.array(value).astype(dtype)
# will give the desired result (the cast overflows).
#   masked_array[b_arr_up == 0] = -1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[101], line 7
#       4 print(masked_array.shape, b_arr_up.shape)
#       5 masked_array[b_arr_up == 0] = -1
# ----> 7 masked_graph, masked_src, masked_sink, masked_weights, x_pos, y_pos, z_pos = create_masked_directed_energy_graph_from_mask(masked_array)
#
# File ~/Documents/VesuviusScroll/GP/3D_sheet_carving/helper.py:174, in create_masked_directed_energy_graph_from_mask(mask_data, direction, large_weight)
#     172 for idx, (i, j, k) in enumerate(non_neg_indices):
#     173     v = g.vertex(idx)
# --> 174     coord_to_vertex[(i, j, k)] = v
#     175     x_prop[v] = k
#     176     y_prop[v] = j
#
# File ~/anaconda3/envs/3d_sheet_carving/lib/python3.12/site-packages/graph_tool/__init__.py:2089, in Graph.vertex(self, i, use_index, add_missing)
#    2086         V = vertices.shape[0] // (1 + len(vprops))
#    2087         return numpy.reshape(vertices, (V, 1 + len(vprops)))
# -> 2089 def vertex(self, i, use_index=True, add_missing=False):
#    2090     """Return the vertex with index ``i``. If ``use_index=False``, the
#    2091     ``i``-th vertex is returned (which can differ from the vertex with index
#    2092     ``i`` in case of filtered graphs).
#    (...)
#    2096     vertex is returned.
#    2097     """
#    2098     v = libcore.get_vertex(self.__graph, int(i), use_index)
#
# KeyboardInterrupt:

# %%
#plot masked array
print(masked_graph.num_vertices(), masked_graph.num_edges(), masked_src, masked_sink)
res_i = 0
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(masked_array[:,slice_index,:])
    elif axis == 2:
        plt.imshow(masked_array[:,:,slice_index])
    else:
        plt.imshow(masked_array[slice_index,:,:])
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=masked_array.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# 485059 2557959 485057 485058
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
#plot label ontop of raw data
res_i = 0
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(mark_boundaries_color(b_arr_up[:,slice_index,:], reduced_mask_data[res_i][:,slice_index,:]))
    elif axis == 2:
        plt.imshow(mark_boundaries_color(b_arr_up[:,:,slice_index], reduced_mask_data[res_i][:,:,slice_index]))
    else:
        plt.imshow(mark_boundaries_color(b_arr_up[slice_index,:,:], reduced_mask_data[res_i][slice_index,:,:]))
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=b_arr_up.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
boundary_array, flow = calculate_seam_iter(masked_graph, masked_src, masked_sink, masked_weights, masked_array.shape[0], x_pos, y_pos, z_pos)
# Out:
# Time taken to calculate max flow boykov: 2.724339008331299
# Time taken to calculate max flow: 0.6301782131195068 flow: 334789
# Time taken to calculate max flow and min cut: 3.686336040496826
# edges that cross the partition: 2557959
# boundary vertices: 123284
# Time taken to calculate seam: 0.07291984558105469
# Time taken to convert boundary vertices to array: 0.46540117263793945

# %%
print("flow:", flow)
print("boundary_array:", np.sum(boundary_array))

# %%
#plot full res boundary array
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(boundary_array[:,slice_index,:])
    elif axis == 2:
        plt.imshow(boundary_array[:,:,slice_index])
    else:
        plt.imshow(boundary_array[slice_index,:,:])
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=boundary_array.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
#plot seam ontop of raw data
res_i = 0
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(mark_boundaries_color(reduced_raw_data[res_i][:,slice_index,:], reduced_mask_data[res_i][:,slice_index,:]))
    elif axis == 2:
        plt.imshow(mark_boundaries_color(reduced_raw_data[res_i][:,:,slice_index], reduced_mask_data[res_i][:,:,slice_index]))
    else:
        plt.imshow(mark_boundaries_color(reduced_raw_data[res_i][slice_index,:,:], reduced_mask_data[res_i][slice_index,:,:]))
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=b_arr_up.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
#plot seam ontop of raw data
res_i = 0
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(mark_boundaries_color(boundary_array[:,slice_index,:], reduced_mask_data[res_i][:,slice_index,:]))
    elif axis == 2:
        plt.imshow(mark_boundaries_color(boundary_array[:,:,slice_index], reduced_mask_data[res_i][:,:,slice_index]))
    else:
        plt.imshow(mark_boundaries_color(boundary_array[slice_index,:,:], reduced_mask_data[res_i][slice_index,:,:]))
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=b_arr_up.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
def multi_res_seam_iter(res_index, mask_array_data, b_arr_up):
    masked_array = mask_array_data[res_index].copy()
    masked_array[b_arr_up == 0] = -1
    stime= time.time()
    directed_graph, src, tgt, weights, x_pos, y_pos, z_pos = create_masked_directed_energy_graph_from_mask(masked_array)
    print(f"Time taken to create graph {res_index}:", time.time()-stime)
    boundary_array, flow = calculate_seam_iter(directed_graph, src, tgt, weights, masked_array.shape[0], x_pos, y_pos, z_pos)
    return boundary_array

def multi_res_seam_calculation(mask_array_data, res_index=3, upscale_factor=2, dilation_amount=1):
    stime= time.time()
    directed_graph, src, tgt, weights, x_pos, y_pos, z_pos = create_masked_directed_energy_graph_from_mask(mask_array_data[res_index])
    print(f"Time taken to create graph {res_index}:", time.time()-stime)
    boundary_array, flow = calculate_seam_iter(directed_graph, src, tgt, weights, mask_array_data[res_index].shape[0], x_pos, y_pos, z_pos)
    b_arr_up = upscale_and_dilate_3d(boundary_array, upscale_factor=2, dilation_amount=dilation_amount)
    for i in range(res_index-1, -1, -1):
        boundary_array = multi_res_seam_iter(i, mask_array_data, b_arr_up)
        b_arr_up = upscale_and_dilate_3d(boundary_array, upscale_factor=upscale_factor, dilation_amount=dilation_amount)
    return boundary_array

# %%
def remove_voxels(data_array, mask_array, boundary_array, num_voxels_to_remove=1, direction='x'):
    """
    Removes a specified number of voxels from each row in the given direction
    based on a boundary mask array.
    
    Parameters:
    data_array (np.ndarray): The original 3D array from which voxels are to be removed.
    boundary_array (np.ndarray): The boundary mask 3D array specifying the voxels to be removed.
    num_voxels_to_remove (int): Number of voxels to be removed from each row.
    direction (str): The direction in which voxels are to be removed ('x', 'y', 'z').
    
    Returns:
    np.ndarray: The resulting 3D array with the specified voxels removed.
    """
    assert data_array.shape == boundary_array.shape, f"Data array and boundary array must have the same shape. {data_array.shape} != {boundary_array.shape}"
    assert mask_array.shape == boundary_array.shape, f"Mask array and boundary array must have the same shape. {mask_array.shape} != {boundary_array.shape}"
    assert direction in ['x', 'y', 'z'], "Direction must be 'x', 'y', or 'z'."
    
    if direction == 'x':
        new_shape = (data_array.shape[0], data_array.shape[1], data_array.shape[2] - num_voxels_to_remove)
        result_data_array = np.zeros(new_shape, dtype=data_array.dtype)
        result_mask_array = np.zeros(new_shape, dtype=mask_array.dtype)
        for i in range(data_array.shape[0]):
            for j in range(data_array.shape[1]):
                data_row = data_array[i, j, :]
                boundary_row = boundary_array[i, j, :]
                keep_indices = np.where(boundary_row == 0)[0]
                keep_indices = keep_indices[:new_shape[2]]  # Only keep up to the new size
                result_data_array[i, j, :] = data_row[keep_indices][:new_shape[2]]
                result_mask_array[i, j, :] = mask_array[i, j, keep_indices][:new_shape[2]]
        
        # Create padded arrays with -1
        padded_data_array = -np.ones_like(data_array, dtype=data_array.dtype)
        padded_mask_array = -np.ones_like(mask_array, dtype=mask_array.dtype)
        
        # Copy the result arrays into the padded arrays
        padded_data_array[:, :, :new_shape[2]] = result_data_array
        padded_mask_array[:, :, :new_shape[2]] = result_mask_array
    
    elif direction == 'y':
        new_shape = (data_array.shape[0], data_array.shape[1] - num_voxels_to_remove, data_array.shape[2])
        result_data_array = np.zeros(new_shape, dtype=data_array.dtype)
        result_mask_array = np.zeros(new_shape, dtype=mask_array.dtype)
        for i in range(data_array.shape[0]):
            for k in range(data_array.shape[2]):
                data_row = data_array[i, :, k]
                boundary_row = boundary_array[i, :, k]
                keep_indices = np.where(boundary_row == 0)[0]
                keep_indices = keep_indices[:new_shape[1]]  # Only keep up to the new size
                result_data_array[i, :, k] = data_row[keep_indices][:new_shape[1]]
                result_mask_array[i, :, k] = mask_array[i, keep_indices, k][:new_shape[1]]
        
        # Create padded arrays with -1
        padded_data_array = -np.ones_like(data_array, dtype=data_array.dtype)
        padded_mask_array = -np.ones_like(mask_array, dtype=mask_array.dtype)
        
        # Copy the result arrays into the padded arrays
        padded_data_array[:, :new_shape[1], :] = result_data_array
        padded_mask_array[:, :new_shape[1], :] = result_mask_array
    
    elif direction == 'z':
        new_shape = (data_array.shape[0] - num_voxels_to_remove, data_array.shape[1], data_array.shape[2])
        result_data_array = np.zeros(new_shape, dtype=data_array.dtype)
        result_mask_array = np.zeros(new_shape, dtype=mask_array.dtype)
        for j in range(data_array.shape[1]):
            for k in range(data_array.shape[2]):
                data_row = data_array[:, j, k]
                boundary_row = boundary_array[:, j, k]
                keep_indices = np.where(boundary_row == 0)[0]
                keep_indices = keep_indices[:new_shape[0]]  # Only keep up to the new size
                result_data_array[:, j, k] = data_row[keep_indices][:new_shape[0]]
                result_mask_array[:, j, k] = mask_array[keep_indices, j, k][:new_shape[0]]
        
        # Create padded arrays with -1
        padded_data_array = -np.ones_like(data_array, dtype=data_array.dtype)
        padded_mask_array = -np.ones_like(mask_array, dtype=mask_array.dtype)
        
        # Copy the result arrays into the padded arrays
        padded_data_array[:new_shape[0], :, :] = result_data_array
        padded_mask_array[:new_shape[0], :, :] = result_mask_array
    
    return padded_data_array, padded_mask_array

# %%
res_index = 2
mask_array_data = reduced_mask_data
raw_array_data = reduced_raw_data[0]
num_seams_to_remove = 80

boundary_arrays = []

for i in range(num_seams_to_remove):
    boundary_array = multi_res_seam_calculation(mask_array_data, res_index, dilation_amount=1)
    mask_array_data, raw_array_data = remove_voxels(mask_array_data[0], raw_array_data, boundary_array)
    mask_array_data = coarsen_image(mask_array_data, 3)
    boundary_arrays.append(boundary_array)

    #TODO: remove seam from mask_array_data

# Get the current timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
# Out:
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.07936692237854
# Time taken to add edges to graph: 2.0081639289855957
# Time taken to add source and sink nodes: 0.08474206924438477
# Time taken to create graph 2: 3.189474105834961
# Time taken to calculate max flow boykov: 3.7671520709991455
# Time taken to calculate max flow: 0.04314279556274414 flow: 13915
# Time taken to calculate max flow and min cut: 0.0985708236694336
# edges that cross the partition: 1540352
# boundary vertices: 7738
# Time taken to calculate seam: 0.023712158203125
# Time taken to convert boundary vertices to array: 0.028883934020996094
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3979339599609375
# Time taken to add edges to graph: 0.6474931240081787
# Time taken to add source and sink nodes: 0.404386043548584
# Time taken to create graph 1: 1.4582710266113281
# Time taken to calculate max flow boykov: 0.2321150302886963
# Time taken to calculate max flow: 0.16801714897155762 flow: 50368
# Time taken to calculate max flow and min cut: 0.3875608444213867
# edges that cross the partition: 495651
# boundary vertices: 30846
# Time taken to calculate seam: 0.01681685447692871
# Time taken to convert boundary vertices to array: 0.11408495903015137
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5739481449127197
# Time taken to add edges to graph: 2.640151023864746
# Time taken to add source and sink nodes: 2.0738251209259033
# Time taken to create graph 0: 6.322795867919922
# Time taken to calculate max flow boykov: 2.7221169471740723
# Time taken to calculate max flow: 0.6574912071228027 flow: 187819
# Time taken to calculate max flow and min cut: 5.833636999130249
# edges that cross the partition: 2002373
# boundary vertices: 123524
# Time taken to calculate seam: 0.05480504035949707
# Time taken to convert boundary vertices to array: 0.46217918395996094
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0384972095489502
# Time taken to add edges to graph: 1.9363090991973877
# Time taken to add source and sink nodes: 0.08031773567199707
# Time taken to create graph 2: 3.072481870651245
# Time taken to calculate max flow boykov: 4.3474249839782715
# Time taken to calculate max flow: 0.04263019561767578 flow: 14437
# Time taken to calculate max flow and min cut: 0.09172201156616211
# edges that cross the partition: 1516032
# boundary vertices: 7807
# Time taken to calculate seam: 0.02019190788269043
# Time taken to convert boundary vertices to array: 0.02759575843811035
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3946199417114258
# Time taken to add edges to graph: 0.6296889781951904
# Time taken to add source and sink nodes: 0.39893198013305664
# Time taken to create graph 1: 1.431102991104126
# Time taken to calculate max flow boykov: 0.21685099601745605
# Time taken to calculate max flow: 0.16484665870666504 flow: 51385
# Time taken to calculate max flow and min cut: 0.33902883529663086
# edges that cross the partition: 507652
# boundary vertices: 31174
# Time taken to calculate seam: 0.015644073486328125
# Time taken to convert boundary vertices to array: 0.1104280948638916
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.6388530731201172
# Time taken to add edges to graph: 2.75205397605896
# Time taken to add source and sink nodes: 1.9553968906402588
# Time taken to create graph 0: 6.380460977554321
# Time taken to calculate max flow boykov: 2.71002197265625
# Time taken to calculate max flow: 0.6624469757080078 flow: 188719
# Time taken to calculate max flow and min cut: 5.406662940979004
# edges that cross the partition: 2033973
# boundary vertices: 125097
# Time taken to calculate seam: 0.05911874771118164
# Time taken to convert boundary vertices to array: 0.4639749526977539
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.034132957458496
# Time taken to add edges to graph: 1.9105870723724365
# Time taken to add source and sink nodes: 0.08170700073242188
# Time taken to create graph 2: 3.0435421466827393
# Time taken to calculate max flow boykov: 5.459325313568115
# Time taken to calculate max flow: 0.0433201789855957 flow: 14698
# Time taken to calculate max flow and min cut: 0.09891200065612793
# edges that cross the partition: 1516032
# boundary vertices: 7776
# Time taken to calculate seam: 0.02047586441040039
# Time taken to convert boundary vertices to array: 0.02881622314453125
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.38900303840637207
# Time taken to add edges to graph: 0.6352059841156006
# Time taken to add source and sink nodes: 0.39574503898620605
# Time taken to create graph 1: 1.4284119606018066
# Time taken to calculate max flow boykov: 0.21419906616210938
# Time taken to calculate max flow: 0.16681694984436035 flow: 52105
# Time taken to calculate max flow and min cut: 0.3488919734954834
# edges that cross the partition: 501218
# boundary vertices: 30988
# Time taken to calculate seam: 0.015918970108032227
# Time taken to convert boundary vertices to array: 0.11079192161560059
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5655760765075684
# Time taken to add edges to graph: 2.6026499271392822
# Time taken to add source and sink nodes: 1.964698076248169
# Time taken to create graph 0: 6.165359735488892
# Time taken to calculate max flow boykov: 2.737820863723755
# Time taken to calculate max flow: 0.6641511917114258 flow: 191293
# Time taken to calculate max flow and min cut: 5.5192649364471436
# edges that cross the partition: 2021064
# boundary vertices: 124294
# Time taken to calculate seam: 0.05675792694091797
# Time taken to convert boundary vertices to array: 0.4585108757019043
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9986350536346436
# Time taken to add edges to graph: 1.9663729667663574
# Time taken to add source and sink nodes: 0.08246302604675293
# Time taken to create graph 2: 3.063978910446167
# Time taken to calculate max flow boykov: 6.405754804611206
# Time taken to calculate max flow: 0.04343295097351074 flow: 14896
# Time taken to calculate max flow and min cut: 0.09481692314147949
# edges that cross the partition: 1516032
# boundary vertices: 7750
# Time taken to calculate seam: 0.020824909210205078
# Time taken to convert boundary vertices to array: 0.028297901153564453
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.38947510719299316
# Time taken to add edges to graph: 0.6347959041595459
# Time taken to add source and sink nodes: 0.3957810401916504
# Time taken to create graph 1: 1.4294230937957764
# Time taken to calculate max flow boykov: 0.21971511840820312
# Time taken to calculate max flow: 0.166107177734375 flow: 52132
# Time taken to calculate max flow and min cut: 0.3612182140350342
# edges that cross the partition: 498644
# boundary vertices: 30812
# Time taken to calculate seam: 0.017053842544555664
# Time taken to convert boundary vertices to array: 0.11060285568237305
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5708186626434326
# Time taken to add edges to graph: 2.5737240314483643
# Time taken to add source and sink nodes: 1.9434728622436523
# Time taken to create graph 0: 6.12294602394104
# Time taken to calculate max flow boykov: 2.677161931991577
# Time taken to calculate max flow: 0.6519069671630859 flow: 192589
# Time taken to calculate max flow and min cut: 5.533046007156372
# edges that cross the partition: 2008359
# boundary vertices: 123636
# Time taken to calculate seam: 0.05114388465881348
# Time taken to convert boundary vertices to array: 0.45244479179382324
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0594449043273926
# Time taken to add edges to graph: 1.9362249374389648
# Time taken to add source and sink nodes: 0.08428192138671875
# Time taken to create graph 2: 3.098335027694702
# Time taken to calculate max flow boykov: 8.06739091873169
# Time taken to calculate max flow: 0.04252004623413086 flow: 15211
# Time taken to calculate max flow and min cut: 0.09411191940307617
# edges that cross the partition: 1516032
# boundary vertices: 7742
# Time taken to calculate seam: 0.020270824432373047
# Time taken to convert boundary vertices to array: 0.02783513069152832
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3787682056427002
# Time taken to add edges to graph: 0.6138961315155029
# Time taken to add source and sink nodes: 0.39531993865966797
# Time taken to create graph 1: 1.3960740566253662
# Time taken to calculate max flow boykov: 0.2122800350189209
# Time taken to calculate max flow: 0.16658782958984375 flow: 53140
# Time taken to calculate max flow and min cut: 0.3670530319213867
# edges that cross the partition: 493549
# boundary vertices: 30805
# Time taken to calculate seam: 0.015480995178222656
# Time taken to convert boundary vertices to array: 0.1091609001159668
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.560318946838379
# Time taken to add edges to graph: 2.589237928390503
# Time taken to add source and sink nodes: 2.0456860065460205
# Time taken to create graph 0: 6.228294849395752
# Time taken to calculate max flow boykov: 2.701746940612793
# Time taken to calculate max flow: 0.6652801036834717 flow: 196000
# Time taken to calculate max flow and min cut: 5.465145111083984
# edges that cross the partition: 2001949
# boundary vertices: 123614
# Time taken to calculate seam: 0.05286097526550293
# Time taken to convert boundary vertices to array: 0.49443602561950684
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0150551795959473
# Time taken to add edges to graph: 1.9050168991088867
# Time taken to add source and sink nodes: 0.08162593841552734
# Time taken to create graph 2: 3.0194711685180664
# Time taken to calculate max flow boykov: 10.50861382484436
# Time taken to calculate max flow: 0.04168891906738281 flow: 15463
# Time taken to calculate max flow and min cut: 0.08564877510070801
# edges that cross the partition: 1491712
# boundary vertices: 7756
# Time taken to calculate seam: 0.020094871520996094
# Time taken to convert boundary vertices to array: 0.02758002281188965
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3926279544830322
# Time taken to add edges to graph: 0.6345679759979248
# Time taken to add source and sink nodes: 0.4127950668334961
# Time taken to create graph 1: 1.4481170177459717
# Time taken to calculate max flow boykov: 0.2203230857849121
# Time taken to calculate max flow: 0.16795802116394043 flow: 54796
# Time taken to calculate max flow and min cut: 0.3395042419433594
# edges that cross the partition: 508791
# boundary vertices: 30920
# Time taken to calculate seam: 0.016378164291381836
# Time taken to convert boundary vertices to array: 0.10992789268493652
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5970706939697266
# Time taken to add edges to graph: 2.582552909851074
# Time taken to add source and sink nodes: 1.955169677734375
# Time taken to create graph 0: 6.166790246963501
# Time taken to calculate max flow boykov: 2.706743001937866
# Time taken to calculate max flow: 0.6620540618896484 flow: 200293
# Time taken to calculate max flow and min cut: 5.246116876602173
# edges that cross the partition: 2027087
# boundary vertices: 123666
# Time taken to calculate seam: 0.05539679527282715
# Time taken to convert boundary vertices to array: 0.45302295684814453
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.6485259532928467
# Time taken to add edges to graph: 1.8582329750061035
# Time taken to add source and sink nodes: 0.08428597450256348
# Time taken to create graph 2: 3.6084790229797363
# Time taken to calculate max flow boykov: 9.11104679107666
# Time taken to calculate max flow: 0.042517900466918945 flow: 15445
# Time taken to calculate max flow and min cut: 0.08960509300231934
# edges that cross the partition: 1491712
# boundary vertices: 7804
# Time taken to calculate seam: 0.019646883010864258
# Time taken to convert boundary vertices to array: 0.027156829833984375
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.38997817039489746
# Time taken to add edges to graph: 0.6295161247253418
# Time taken to add source and sink nodes: 0.39273500442504883
# Time taken to create graph 1: 1.4210460186004639
# Time taken to calculate max flow boykov: 0.2145521640777588
# Time taken to calculate max flow: 0.1663961410522461 flow: 53455
# Time taken to calculate max flow and min cut: 0.3536698818206787
# edges that cross the partition: 508058
# boundary vertices: 31052
# Time taken to calculate seam: 0.014904975891113281
# Time taken to convert boundary vertices to array: 0.1088871955871582
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5886871814727783
# Time taken to add edges to graph: 2.588676929473877
# Time taken to add source and sink nodes: 2.002701997756958
# Time taken to create graph 0: 6.212741851806641
# Time taken to calculate max flow boykov: 2.7050700187683105
# Time taken to calculate max flow: 0.661444902420044 flow: 195775
# Time taken to calculate max flow and min cut: 5.419497966766357
# edges that cross the partition: 2030803
# boundary vertices: 124768
# Time taken to calculate seam: 0.0580439567565918
# Time taken to convert boundary vertices to array: 0.4894232749938965
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9913852214813232
# Time taken to add edges to graph: 1.8446781635284424
# Time taken to add source and sink nodes: 0.08115768432617188
# Time taken to create graph 2: 2.9338018894195557
# Time taken to calculate max flow boykov: 8.495690107345581
# Time taken to calculate max flow: 0.042582035064697266 flow: 15481
# Time taken to calculate max flow and min cut: 0.07673120498657227
# edges that cross the partition: 1491712
# boundary vertices: 7665
# Time taken to calculate seam: 0.019631147384643555
# Time taken to convert boundary vertices to array: 0.027573108673095703
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3824300765991211
# Time taken to add edges to graph: 0.6185190677642822
# Time taken to add source and sink nodes: 0.3951289653778076
# Time taken to create graph 1: 1.4049551486968994
# Time taken to calculate max flow boykov: 0.2221212387084961
# Time taken to calculate max flow: 0.16585397720336914 flow: 55561
# Time taken to calculate max flow and min cut: 0.33782386779785156
# edges that cross the partition: 499297
# boundary vertices: 30307
# Time taken to calculate seam: 0.015568971633911133
# Time taken to convert boundary vertices to array: 0.11041998863220215
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5729598999023438
# Time taken to add edges to graph: 2.5295658111572266
# Time taken to add source and sink nodes: 2.010869026184082
# Time taken to create graph 0: 6.146464109420776
# Time taken to calculate max flow boykov: 2.7349209785461426
# Time taken to calculate max flow: 0.6564898490905762 flow: 205234
# Time taken to calculate max flow and min cut: 5.237028121948242
# edges that cross the partition: 1990510
# boundary vertices: 120274
# Time taken to calculate seam: 0.0560755729675293
# Time taken to convert boundary vertices to array: 0.4542989730834961
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0044701099395752
# Time taken to add edges to graph: 1.8680052757263184
# Time taken to add source and sink nodes: 0.08081698417663574
# Time taken to create graph 2: 2.9704811573028564
# Time taken to calculate max flow boykov: 10.160382986068726
# Time taken to calculate max flow: 0.04256105422973633 flow: 15652
# Time taken to calculate max flow and min cut: 0.08002209663391113
# edges that cross the partition: 1491712
# boundary vertices: 7777
# Time taken to calculate seam: 0.020843982696533203
# Time taken to convert boundary vertices to array: 0.028111934661865234
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3891751766204834
# Time taken to add edges to graph: 0.6311349868774414
# Time taken to add source and sink nodes: 0.401198148727417
# Time taken to create graph 1: 1.4291069507598877
# Time taken to calculate max flow boykov: 0.22098922729492188
# Time taken to calculate max flow: 0.16530108451843262 flow: 56380
# Time taken to calculate max flow and min cut: 0.33427906036376953
# edges that cross the partition: 506239
# boundary vertices: 30735
# Time taken to calculate seam: 0.015321969985961914
# Time taken to convert boundary vertices to array: 0.11064291000366211
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 2.2746219635009766
# Time taken to add edges to graph: 2.599313974380493
# Time taken to add source and sink nodes: 2.0014379024505615
# Time taken to create graph 0: 6.908019065856934
# Time taken to calculate max flow boykov: 2.749979257583618
# Time taken to calculate max flow: 0.6590530872344971 flow: 208141
# Time taken to calculate max flow and min cut: 5.195870876312256
# edges that cross the partition: 2023726
# boundary vertices: 122734
# Time taken to calculate seam: 0.05816292762756348
# Time taken to convert boundary vertices to array: 0.4555370807647705
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9901759624481201
# Time taken to add edges to graph: 1.8591439723968506
# Time taken to add source and sink nodes: 0.08237290382385254
# Time taken to create graph 2: 2.9478390216827393
# Time taken to calculate max flow boykov: 11.31400203704834
# Time taken to calculate max flow: 0.04297685623168945 flow: 15850
# Time taken to calculate max flow and min cut: 0.08415055274963379
# edges that cross the partition: 1467392
# boundary vertices: 7797
# Time taken to calculate seam: 0.02001023292541504
# Time taken to convert boundary vertices to array: 0.02788686752319336
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3954789638519287
# Time taken to add edges to graph: 0.6446459293365479
# Time taken to add source and sink nodes: 0.39626598358154297
# Time taken to create graph 1: 1.445039987564087
# Time taken to calculate max flow boykov: 0.2237088680267334
# Time taken to calculate max flow: 0.1646730899810791 flow: 56821
# Time taken to calculate max flow and min cut: 0.33588600158691406
# edges that cross the partition: 515113
# boundary vertices: 30886
# Time taken to calculate seam: 0.01650261878967285
# Time taken to convert boundary vertices to array: 0.10947680473327637
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.6151459217071533
# Time taken to add edges to graph: 2.6350197792053223
# Time taken to add source and sink nodes: 2.0099363327026367
# Time taken to create graph 0: 6.295134782791138
# Time taken to calculate max flow boykov: 2.7959280014038086
# Time taken to calculate max flow: 0.6638040542602539 flow: 208330
# Time taken to calculate max flow and min cut: 5.1669721603393555
# edges that cross the partition: 2058192
# boundary vertices: 123555
# Time taken to calculate seam: 0.05464601516723633
# Time taken to convert boundary vertices to array: 0.4588191509246826
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.0028049945831299
# Time taken to add edges to graph: 1.849153995513916
# Time taken to add source and sink nodes: 0.0824127197265625
# Time taken to create graph 2: 2.9507150650024414
# Time taken to calculate max flow boykov: 11.426618099212646
# Time taken to calculate max flow: 0.04330325126647949 flow: 15850
# Time taken to calculate max flow and min cut: 0.08876514434814453
# edges that cross the partition: 1467392
# boundary vertices: 7754
# Time taken to calculate seam: 0.0201718807220459
# Time taken to convert boundary vertices to array: 0.02783989906311035
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.40259599685668945
# Time taken to add edges to graph: 0.656146764755249
# Time taken to add source and sink nodes: 0.3936889171600342
# Time taken to create graph 1: 1.4602181911468506
# Time taken to calculate max flow boykov: 0.22361993789672852
# Time taken to calculate max flow: 0.16796517372131348 flow: 55291
# Time taken to calculate max flow and min cut: 0.33883190155029297
# edges that cross the partition: 507487
# boundary vertices: 30866
# Time taken to calculate seam: 0.016669034957885742
# Time taken to convert boundary vertices to array: 0.1123499870300293
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5986840724945068
# Time taken to add edges to graph: 2.631593942642212
# Time taken to add source and sink nodes: 1.9500889778137207
# Time taken to create graph 0: 6.215998888015747
# Time taken to calculate max flow boykov: 2.72597074508667
# Time taken to calculate max flow: 0.6591401100158691 flow: 201481
# Time taken to calculate max flow and min cut: 5.35074257850647
# edges that cross the partition: 2025664
# boundary vertices: 123449
# Time taken to calculate seam: 0.060884952545166016
# Time taken to convert boundary vertices to array: 0.4643568992614746
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9857940673828125
# Time taken to add edges to graph: 1.8502869606018066
# Time taken to add source and sink nodes: 0.08007502555847168
# Time taken to create graph 2: 2.931427001953125
# Time taken to calculate max flow boykov: 10.19187307357788
# Time taken to calculate max flow: 0.04256105422973633 flow: 15868
# Time taken to calculate max flow and min cut: 0.07607293128967285
# edges that cross the partition: 1467392
# boundary vertices: 7752
# Time taken to calculate seam: 0.020322799682617188
# Time taken to convert boundary vertices to array: 0.027692794799804688
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.38505005836486816
# Time taken to add edges to graph: 0.6262550354003906
# Time taken to add source and sink nodes: 0.394456148147583
# Time taken to create graph 1: 1.4139747619628906
# Time taken to calculate max flow boykov: 0.2201988697052002
# Time taken to calculate max flow: 0.16625285148620605 flow: 56533
# Time taken to calculate max flow and min cut: 0.33673977851867676
# edges that cross the partition: 504234
# boundary vertices: 30644
# Time taken to calculate seam: 0.01610708236694336
# Time taken to convert boundary vertices to array: 0.10991215705871582
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 2.255753993988037
# Time taken to add edges to graph: 2.613903760910034
# Time taken to add source and sink nodes: 2.015897035598755
# Time taken to create graph 0: 6.916945934295654
# Time taken to calculate max flow boykov: 2.7017428874969482
# Time taken to calculate max flow: 0.6592698097229004 flow: 206584
# Time taken to calculate max flow and min cut: 5.151803731918335
# edges that cross the partition: 2009652
# boundary vertices: 122142
# Time taken to calculate seam: 0.06017589569091797
# Time taken to convert boundary vertices to array: 0.4733400344848633
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9916689395904541
# Time taken to add edges to graph: 1.8495879173278809
# Time taken to add source and sink nodes: 0.08261990547180176
# Time taken to create graph 2: 2.940614938735962
# Time taken to calculate max flow boykov: 10.425803899765015
# Time taken to calculate max flow: 0.0423581600189209 flow: 15985
# Time taken to calculate max flow and min cut: 0.09128403663635254
# edges that cross the partition: 1467392
# boundary vertices: 7814
# Time taken to calculate seam: 0.020495891571044922
# Time taken to convert boundary vertices to array: 0.027959108352661133
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3923039436340332
# Time taken to add edges to graph: 0.6363482475280762
# Time taken to add source and sink nodes: 0.3893911838531494
# Time taken to create graph 1: 1.4264070987701416
# Time taken to calculate max flow boykov: 0.21924090385437012
# Time taken to calculate max flow: 0.1648271083831787 flow: 54715
# Time taken to calculate max flow and min cut: 0.3385350704193115
# edges that cross the partition: 507417
# boundary vertices: 31057
# Time taken to calculate seam: 0.016149044036865234
# Time taken to convert boundary vertices to array: 0.10965609550476074
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5928339958190918
# Time taken to add edges to graph: 2.691502094268799
# Time taken to add source and sink nodes: 2.0742738246917725
# Time taken to create graph 0: 6.390862703323364
# Time taken to calculate max flow boykov: 2.7347049713134766
# Time taken to calculate max flow: 0.659264087677002 flow: 199105
# Time taken to calculate max flow and min cut: 5.358366250991821
# edges that cross the partition: 2025429
# boundary vertices: 124383
# Time taken to calculate seam: 0.056433916091918945
# Time taken to convert boundary vertices to array: 0.4660019874572754
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9583768844604492
# Time taken to add edges to graph: 1.7977240085601807
# Time taken to add source and sink nodes: 0.08185386657714844
# Time taken to create graph 2: 2.8550751209259033
# Time taken to calculate max flow boykov: 12.0576491355896
# Time taken to calculate max flow: 0.04228401184082031 flow: 16165
# Time taken to calculate max flow and min cut: 0.08119559288024902
# edges that cross the partition: 1445374
# boundary vertices: 7840
# Time taken to calculate seam: 0.019223928451538086
# Time taken to convert boundary vertices to array: 0.028294801712036133
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.39485597610473633
# Time taken to add edges to graph: 0.6415338516235352
# Time taken to add source and sink nodes: 0.4049551486968994
# Time taken to create graph 1: 1.4496748447418213
# Time taken to calculate max flow boykov: 0.2335648536682129
# Time taken to calculate max flow: 0.16570758819580078 flow: 58207
# Time taken to calculate max flow and min cut: 0.33353590965270996
# edges that cross the partition: 518619
# boundary vertices: 31146
# Time taken to calculate seam: 0.015800952911376953
# Time taken to convert boundary vertices to array: 0.11288809776306152
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.6193501949310303
# Time taken to add edges to graph: 2.6763641834259033
# Time taken to add source and sink nodes: 2.032304048538208
# Time taken to create graph 0: 6.3629162311553955
# Time taken to calculate max flow boykov: 2.7838728427886963
# Time taken to calculate max flow: 0.6642918586730957 flow: 213055
# Time taken to calculate max flow and min cut: 5.193631887435913
# edges that cross the partition: 2077601
# boundary vertices: 124578
# Time taken to calculate seam: 0.053904056549072266
# Time taken to convert boundary vertices to array: 0.4632558822631836
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9654510021209717
# Time taken to add edges to graph: 1.7864298820495605
# Time taken to add source and sink nodes: 0.08309006690979004
# Time taken to create graph 2: 2.851151943206787
# Time taken to calculate max flow boykov: 9.916530847549438
# Time taken to calculate max flow: 0.04226493835449219 flow: 16138
# Time taken to calculate max flow and min cut: 0.09063100814819336
# edges that cross the partition: 1444830
# boundary vertices: 7813
# Time taken to calculate seam: 0.02086186408996582
# Time taken to convert boundary vertices to array: 0.0277559757232666
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3873019218444824
# Time taken to add edges to graph: 0.6382839679718018
# Time taken to add source and sink nodes: 0.3962061405181885
# Time taken to create graph 1: 1.4300119876861572
# Time taken to calculate max flow boykov: 0.22092103958129883
# Time taken to calculate max flow: 0.16753625869750977 flow: 58198
# Time taken to calculate max flow and min cut: 0.33083200454711914
# edges that cross the partition: 509379
# boundary vertices: 31207
# Time taken to calculate seam: 0.015339136123657227
# Time taken to convert boundary vertices to array: 0.10837101936340332
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.59138822555542
# Time taken to add edges to graph: 2.616408109664917
# Time taken to add source and sink nodes: 1.9825329780578613
# Time taken to create graph 0: 6.223221063613892
# Time taken to calculate max flow boykov: 2.72487211227417
# Time taken to calculate max flow: 0.658193826675415 flow: 213100
# Time taken to calculate max flow and min cut: 5.065381050109863
# edges that cross the partition: 2035656
# boundary vertices: 124793
# Time taken to calculate seam: 0.055711984634399414
# Time taken to convert boundary vertices to array: 0.45923924446105957
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.6252269744873047
# Time taken to add edges to graph: 1.8212041854858398
# Time taken to add source and sink nodes: 0.08295083045959473
# Time taken to create graph 2: 3.5458009243011475
# Time taken to calculate max flow boykov: 9.797641038894653
# Time taken to calculate max flow: 0.04288673400878906 flow: 16183
# Time taken to calculate max flow and min cut: 0.09243583679199219
# edges that cross the partition: 1443072
# boundary vertices: 7783
# Time taken to calculate seam: 0.020446062088012695
# Time taken to convert boundary vertices to array: 0.02823495864868164
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.38968896865844727
# Time taken to add edges to graph: 0.6431710720062256
# Time taken to add source and sink nodes: 0.39681410789489746
# Time taken to create graph 1: 1.4378411769866943
# Time taken to calculate max flow boykov: 0.2197742462158203
# Time taken to calculate max flow: 0.1667330265045166 flow: 56074
# Time taken to calculate max flow and min cut: 0.3445241451263428
# edges that cross the partition: 503473
# boundary vertices: 30995
# Time taken to calculate seam: 0.015521049499511719
# Time taken to convert boundary vertices to array: 0.11015081405639648
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.590480089187622
# Time taken to add edges to graph: 2.6105270385742188
# Time taken to add source and sink nodes: 1.965926170349121
# Time taken to create graph 0: 6.2001731395721436
# Time taken to calculate max flow boykov: 2.7445240020751953
# Time taken to calculate max flow: 0.6655409336090088 flow: 203227
# Time taken to calculate max flow and min cut: 5.268144845962524
# edges that cross the partition: 2026068
# boundary vertices: 124031
# Time taken to calculate seam: 0.05881619453430176
# Time taken to convert boundary vertices to array: 0.461698055267334
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9682140350341797
# Time taken to add edges to graph: 1.8280351161956787
# Time taken to add source and sink nodes: 0.08230805397033691
# Time taken to create graph 2: 2.895632028579712
# Time taken to calculate max flow boykov: 10.117812871932983
# Time taken to calculate max flow: 0.042958736419677734 flow: 16201
# Time taken to calculate max flow and min cut: 0.07653307914733887
# edges that cross the partition: 1443072
# boundary vertices: 7757
# Time taken to calculate seam: 0.0184628963470459
# Time taken to convert boundary vertices to array: 0.027647972106933594
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.39038586616516113
# Time taken to add edges to graph: 0.6338398456573486
# Time taken to add source and sink nodes: 0.399932861328125
# Time taken to create graph 1: 1.4324798583984375
# Time taken to calculate max flow boykov: 0.22069287300109863
# Time taken to calculate max flow: 0.16595673561096191 flow: 57586
# Time taken to calculate max flow and min cut: 0.3420131206512451
# edges that cross the partition: 503506
# boundary vertices: 30677
# Time taken to calculate seam: 0.017097949981689453
# Time taken to convert boundary vertices to array: 0.11171889305114746
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5777647495269775
# Time taken to add edges to graph: 2.5520520210266113
# Time taken to add source and sink nodes: 2.0278429985046387
# Time taken to create graph 0: 6.190674304962158
# Time taken to calculate max flow boykov: 2.7188777923583984
# Time taken to calculate max flow: 0.6606078147888184 flow: 211309
# Time taken to calculate max flow and min cut: 5.143747806549072
# edges that cross the partition: 2011355
# boundary vertices: 121913
# Time taken to calculate seam: 0.05684208869934082
# Time taken to convert boundary vertices to array: 0.4800379276275635
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9564940929412842
# Time taken to add edges to graph: 1.8093678951263428
# Time taken to add source and sink nodes: 0.08305883407592773
# Time taken to create graph 2: 2.8651340007781982
# Time taken to calculate max flow boykov: 11.91204571723938
# Time taken to calculate max flow: 0.04328012466430664 flow: 16354
# Time taken to calculate max flow and min cut: 0.09096288681030273
# edges that cross the partition: 1425843
# boundary vertices: 7747
# Time taken to calculate seam: 0.019639015197753906
# Time taken to convert boundary vertices to array: 0.02870917320251465
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3940110206604004
# Time taken to add edges to graph: 0.6354720592498779
# Time taken to add source and sink nodes: 0.40032005310058594
# Time taken to create graph 1: 1.4381420612335205
# Time taken to calculate max flow boykov: 0.22964024543762207
# Time taken to calculate max flow: 0.16544508934020996 flow: 58252
# Time taken to calculate max flow and min cut: 0.336806058883667
# edges that cross the partition: 506459
# boundary vertices: 30867
# Time taken to calculate seam: 0.015980958938598633
# Time taken to convert boundary vertices to array: 0.11103677749633789
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5972568988800049
# Time taken to add edges to graph: 2.65742826461792
# Time taken to add source and sink nodes: 1.976355791091919
# Time taken to create graph 0: 6.265840768814087
# Time taken to calculate max flow boykov: 2.6864089965820312
# Time taken to calculate max flow: 0.6638088226318359 flow: 211804
# Time taken to calculate max flow and min cut: 5.1222991943359375
# edges that cross the partition: 2031772
# boundary vertices: 123668
# Time taken to calculate seam: 0.05615711212158203
# Time taken to convert boundary vertices to array: 0.4476969242095947
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.587144136428833
# Time taken to add edges to graph: 1.7445921897888184
# Time taken to add source and sink nodes: 0.08370590209960938
# Time taken to create graph 2: 3.4336111545562744
# Time taken to calculate max flow boykov: 11.917978286743164
# Time taken to calculate max flow: 0.04318523406982422 flow: 16381
# Time taken to calculate max flow and min cut: 0.07820987701416016
# edges that cross the partition: 1424627
# boundary vertices: 7792
# Time taken to calculate seam: 0.019995927810668945
# Time taken to convert boundary vertices to array: 0.028715133666992188
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3806030750274658
# Time taken to add edges to graph: 0.6197030544281006
# Time taken to add source and sink nodes: 0.38867878913879395
# Time taken to create graph 1: 1.3970258235931396
# Time taken to calculate max flow boykov: 0.23554182052612305
# Time taken to calculate max flow: 0.16520190238952637 flow: 58027
# Time taken to calculate max flow and min cut: 0.3358027935028076
# edges that cross the partition: 506576
# boundary vertices: 30697
# Time taken to calculate seam: 0.01651477813720703
# Time taken to convert boundary vertices to array: 0.10968565940856934
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5670790672302246
# Time taken to add edges to graph: 2.532431125640869
# Time taken to add source and sink nodes: 2.2403900623321533
# Time taken to create graph 0: 6.376266002655029
# Time taken to calculate max flow boykov: 2.654197931289673
# Time taken to calculate max flow: 0.6456029415130615 flow: 212488
# Time taken to calculate max flow and min cut: 5.224016904830933
# edges that cross the partition: 2010869
# boundary vertices: 122246
# Time taken to calculate seam: 0.058029890060424805
# Time taken to convert boundary vertices to array: 0.4552288055419922
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9584238529205322
# Time taken to add edges to graph: 1.772402048110962
# Time taken to add source and sink nodes: 0.08185887336730957
# Time taken to create graph 2: 2.829152822494507
# Time taken to calculate max flow boykov: 10.084935903549194
# Time taken to calculate max flow: 0.04262208938598633 flow: 16417
# Time taken to calculate max flow and min cut: 0.08944988250732422
# edges that cross the partition: 1418752
# boundary vertices: 7798
# Time taken to calculate seam: 0.018374919891357422
# Time taken to convert boundary vertices to array: 0.02813410758972168
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3915290832519531
# Time taken to add edges to graph: 0.6381151676177979
# Time taken to add source and sink nodes: 0.3997459411621094
# Time taken to create graph 1: 1.4378890991210938
# Time taken to calculate max flow boykov: 0.22383379936218262
# Time taken to calculate max flow: 0.16769623756408691 flow: 59323
# Time taken to calculate max flow and min cut: 0.33476805686950684
# edges that cross the partition: 507494
# boundary vertices: 30993
# Time taken to calculate seam: 0.016488075256347656
# Time taken to convert boundary vertices to array: 0.11060571670532227
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5988142490386963
# Time taken to add edges to graph: 2.5730812549591064
# Time taken to add source and sink nodes: 1.9706940650939941
# Time taken to create graph 0: 6.175185918807983
# Time taken to calculate max flow boykov: 2.7350969314575195
# Time taken to calculate max flow: 0.6639969348907471 flow: 215773
# Time taken to calculate max flow and min cut: 5.1374311447143555
# edges that cross the partition: 2032803
# boundary vertices: 124075
# Time taken to calculate seam: 0.060913801193237305
# Time taken to convert boundary vertices to array: 0.46994471549987793
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9556169509887695
# Time taken to add edges to graph: 1.782820224761963
# Time taken to add source and sink nodes: 0.08223891258239746
# Time taken to create graph 2: 2.8365747928619385
# Time taken to calculate max flow boykov: 9.419016122817993
# Time taken to calculate max flow: 0.04263615608215332 flow: 16453
# Time taken to calculate max flow and min cut: 0.07853913307189941
# edges that cross the partition: 1418752
# boundary vertices: 7854
# Time taken to calculate seam: 0.018511056900024414
# Time taken to convert boundary vertices to array: 0.028157949447631836
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.4001891613006592
# Time taken to add edges to graph: 0.650813102722168
# Time taken to add source and sink nodes: 0.39975881576538086
# Time taken to create graph 1: 1.4590179920196533
# Time taken to calculate max flow boykov: 0.22675299644470215
# Time taken to calculate max flow: 0.16773390769958496 flow: 55831
# Time taken to calculate max flow and min cut: 0.33376002311706543
# edges that cross the partition: 519293
# boundary vertices: 31248
# Time taken to calculate seam: 0.015382051467895508
# Time taken to convert boundary vertices to array: 0.11133718490600586
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 2.2765109539031982
# Time taken to add edges to graph: 2.658830165863037
# Time taken to add source and sink nodes: 2.165015935897827
# Time taken to create graph 0: 7.13399600982666
# Time taken to calculate max flow boykov: 2.8017821311950684
# Time taken to calculate max flow: 0.6550259590148926 flow: 200176
# Time taken to calculate max flow and min cut: 5.055630207061768
# edges that cross the partition: 2065858
# boundary vertices: 124721
# Time taken to calculate seam: 0.05275130271911621
# Time taken to convert boundary vertices to array: 0.45689916610717773
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9542028903961182
# Time taken to add edges to graph: 1.7524337768554688
# Time taken to add source and sink nodes: 0.08138608932495117
# Time taken to create graph 2: 2.8043718338012695
# Time taken to calculate max flow boykov: 9.89270305633545
# Time taken to calculate max flow: 0.042294979095458984 flow: 16633
# Time taken to calculate max flow and min cut: 0.08285188674926758
# edges that cross the partition: 1402502
# boundary vertices: 7783
# Time taken to calculate seam: 0.018709897994995117
# Time taken to convert boundary vertices to array: 0.02765178680419922
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3907787799835205
# Time taken to add edges to graph: 0.6347336769104004
# Time taken to add source and sink nodes: 0.39786291122436523
# Time taken to create graph 1: 1.4327940940856934
# Time taken to calculate max flow boykov: 0.22313594818115234
# Time taken to calculate max flow: 0.16735100746154785 flow: 56452
# Time taken to calculate max flow and min cut: 0.33014798164367676
# edges that cross the partition: 511305
# boundary vertices: 30980
# Time taken to calculate seam: 0.016809940338134766
# Time taken to convert boundary vertices to array: 0.11059379577636719
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5903916358947754
# Time taken to add edges to graph: 2.5615007877349854
# Time taken to add source and sink nodes: 2.134645938873291
# Time taken to create graph 0: 6.32072901725769
# Time taken to calculate max flow boykov: 2.721665143966675
# Time taken to calculate max flow: 0.6562068462371826 flow: 204334
# Time taken to calculate max flow and min cut: 5.138088941574097
# edges that cross the partition: 2036858
# boundary vertices: 123932
# Time taken to calculate seam: 0.05241799354553223
# Time taken to convert boundary vertices to array: 0.45084285736083984
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9346888065338135
# Time taken to add edges to graph: 1.7612049579620361
# Time taken to add source and sink nodes: 0.08196401596069336
# Time taken to create graph 2: 2.793694019317627
# Time taken to calculate max flow boykov: 10.845884799957275
# Time taken to calculate max flow: 0.04270005226135254 flow: 16732
# Time taken to calculate max flow and min cut: 0.07513117790222168
# edges that cross the partition: 1401548
# boundary vertices: 7768
# Time taken to calculate seam: 0.019700288772583008
# Time taken to convert boundary vertices to array: 0.027638912200927734
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3917248249053955
# Time taken to add edges to graph: 0.634162187576294
# Time taken to add source and sink nodes: 0.39853382110595703
# Time taken to create graph 1: 1.4325382709503174
# Time taken to calculate max flow boykov: 0.222944974899292
# Time taken to calculate max flow: 0.16686701774597168 flow: 57757
# Time taken to calculate max flow and min cut: 0.3410799503326416
# edges that cross the partition: 505413
# boundary vertices: 30620
# Time taken to calculate seam: 0.015591144561767578
# Time taken to convert boundary vertices to array: 0.11149811744689941
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5517821311950684
# Time taken to add edges to graph: 2.540862798690796
# Time taken to add source and sink nodes: 2.0104057788848877
# Time taken to create graph 0: 6.1344311237335205
# Time taken to calculate max flow boykov: 2.702558994293213
# Time taken to calculate max flow: 0.6640980243682861 flow: 209572
# Time taken to calculate max flow and min cut: 5.334696292877197
# edges that cross the partition: 2013998
# boundary vertices: 121940
# Time taken to calculate seam: 0.05727100372314453
# Time taken to convert boundary vertices to array: 0.47412800788879395
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9329729080200195
# Time taken to add edges to graph: 1.7423150539398193
# Time taken to add source and sink nodes: 0.08369803428649902
# Time taken to create graph 2: 2.7749500274658203
# Time taken to calculate max flow boykov: 9.187501907348633
# Time taken to calculate max flow: 0.042350053787231445 flow: 16759
# Time taken to calculate max flow and min cut: 0.08065509796142578
# edges that cross the partition: 1394432
# boundary vertices: 7796
# Time taken to calculate seam: 0.01886582374572754
# Time taken to convert boundary vertices to array: 0.02780294418334961
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.39568495750427246
# Time taken to add edges to graph: 0.6515467166900635
# Time taken to add source and sink nodes: 0.40305376052856445
# Time taken to create graph 1: 1.4590919017791748
# Time taken to calculate max flow boykov: 0.23058700561523438
# Time taken to calculate max flow: 0.1676931381225586 flow: 57460
# Time taken to calculate max flow and min cut: 0.34215617179870605
# edges that cross the partition: 515826
# boundary vertices: 30905
# Time taken to calculate seam: 0.016541004180908203
# Time taken to convert boundary vertices to array: 0.11273312568664551
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.6021230220794678
# Time taken to add edges to graph: 2.7011709213256836
# Time taken to add source and sink nodes: 2.0732858180999756
# Time taken to create graph 0: 6.409911870956421
# Time taken to calculate max flow boykov: 2.8268370628356934
# Time taken to calculate max flow: 0.6547248363494873 flow: 208420
# Time taken to calculate max flow and min cut: 5.222264051437378
# edges that cross the partition: 2054188
# boundary vertices: 123133
# Time taken to calculate seam: 0.05329775810241699
# Time taken to convert boundary vertices to array: 0.4625427722930908
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 1.6115612983703613
# Time taken to add edges to graph: 1.7545089721679688
# Time taken to add source and sink nodes: 0.0818181037902832
# Time taken to create graph 2: 3.464017152786255
# Time taken to calculate max flow boykov: 13.324381113052368
# Time taken to calculate max flow: 0.042498111724853516 flow: 16957
# Time taken to calculate max flow and min cut: 0.07369327545166016
# edges that cross the partition: 1394432
# boundary vertices: 7726
# Time taken to calculate seam: 0.0193789005279541
# Time taken to convert boundary vertices to array: 0.027647972106933594
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.38318586349487305
# Time taken to add edges to graph: 0.6335752010345459
# Time taken to add source and sink nodes: 0.40024495124816895
# Time taken to create graph 1: 1.425591230392456
# Time taken to calculate max flow boykov: 0.22411584854125977
# Time taken to calculate max flow: 0.16777300834655762 flow: 59377
# Time taken to calculate max flow and min cut: 0.3429219722747803
# edges that cross the partition: 500421
# boundary vertices: 30471
# Time taken to calculate seam: 0.016274213790893555
# Time taken to convert boundary vertices to array: 0.11267375946044922
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5771479606628418
# Time taken to add edges to graph: 2.5596110820770264
# Time taken to add source and sink nodes: 1.9773430824279785
# Time taken to create graph 0: 6.146872043609619
# Time taken to calculate max flow boykov: 2.709352970123291
# Time taken to calculate max flow: 0.6622052192687988 flow: 217186
# Time taken to calculate max flow and min cut: 5.262537956237793
# edges that cross the partition: 1997403
# boundary vertices: 121924
# Time taken to calculate seam: 0.059689998626708984
# Time taken to convert boundary vertices to array: 0.4625520706176758
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9086928367614746
# Time taken to add edges to graph: 1.758983850479126
# Time taken to add source and sink nodes: 0.0838327407836914
# Time taken to create graph 2: 2.7671849727630615
# Time taken to calculate max flow boykov: 14.337231874465942
# Time taken to calculate max flow: 0.04256010055541992 flow: 17092
# Time taken to calculate max flow and min cut: 0.07526278495788574
# edges that cross the partition: 1378387
# boundary vertices: 7659
# Time taken to calculate seam: 0.019635915756225586
# Time taken to convert boundary vertices to array: 0.02824115753173828
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.37825703620910645
# Time taken to add edges to graph: 0.6084990501403809
# Time taken to add source and sink nodes: 0.3929710388183594
# Time taken to create graph 1: 1.3880419731140137
# Time taken to calculate max flow boykov: 0.21860909461975098
# Time taken to calculate max flow: 0.1662430763244629 flow: 60160
# Time taken to calculate max flow and min cut: 0.3533971309661865
# edges that cross the partition: 492599
# boundary vertices: 30098
# Time taken to calculate seam: 0.016119956970214844
# Time taken to convert boundary vertices to array: 0.10819888114929199
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5399580001831055
# Time taken to add edges to graph: 2.477530002593994
# Time taken to add source and sink nodes: 1.9868950843811035
# Time taken to create graph 0: 6.034517765045166
# Time taken to calculate max flow boykov: 2.683480978012085
# Time taken to calculate max flow: 0.6455130577087402 flow: 219886
# Time taken to calculate max flow and min cut: 5.256638050079346
# edges that cross the partition: 1961365
# boundary vertices: 119638
# Time taken to calculate seam: 0.051622867584228516
# Time taken to convert boundary vertices to array: 0.4524679183959961
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.9302248954772949
# ...
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.39792704582214355
# Time taken to add edges to graph: 0.6494200229644775
# Time taken to add source and sink nodes: 0.4160428047180176
# Time taken to create graph 1: 1.4718520641326904
# Time taken to calculate max flow boykov: 0.23023700714111328
# Time taken to calculate max flow: 0.16540002822875977 flow: 70447
# Time taken to calculate max flow and min cut: 0.3295111656188965
# edges that cross the partition: 516165
# boundary vertices: 30514
# Time taken to calculate seam: 0.018187999725341797
# Time taken to convert boundary vertices to array: 0.1113731861114502
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.6171050071716309
# Time taken to add edges to graph: 2.78830623626709
# Time taken to add source and sink nodes: 2.5728073120117188
# Time taken to create graph 0: 7.012847185134888
# Time taken to calculate max flow boykov: 2.7472598552703857
# Time taken to calculate max flow: 0.6551039218902588 flow: 252241
# Time taken to calculate max flow and min cut: 5.129462242126465
# edges that cross the partition: 2053366
# boundary vertices: 121601
# Time taken to calculate seam: 0.05721688270568848
# Time taken to convert boundary vertices to array: 0.47724413871765137
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.7407901287078857
# Time taken to add edges to graph: 1.3813059329986572
# Time taken to add source and sink nodes: 0.08719897270202637
# Time taken to create graph 2: 2.2242209911346436
# Time taken to calculate max flow boykov: 6.1441638469696045
# Time taken to calculate max flow: 0.04245400428771973 flow: 20278
# Time taken to calculate max flow and min cut: 0.06876087188720703
# edges that cross the partition: 1102592
# boundary vertices: 7721
# Time taken to calculate seam: 0.015583038330078125
# Time taken to convert boundary vertices to array: 0.027502059936523438
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.38845181465148926
# Time taken to add edges to graph: 0.624230146408081
# Time taken to add source and sink nodes: 0.39470410346984863
# Time taken to create graph 1: 1.415832757949829
# Time taken to calculate max flow boykov: 0.21999096870422363
# Time taken to calculate max flow: 0.16832900047302246 flow: 72166
# Time taken to calculate max flow and min cut: 0.35234999656677246
# edges that cross the partition: 509463
# boundary vertices: 30380
# Time taken to calculate seam: 0.016974210739135742
# Time taken to convert boundary vertices to array: 0.1092228889465332
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5672528743743896
# Time taken to add edges to graph: 2.545908212661743
# Time taken to add source and sink nodes: 1.9895009994506836
# Time taken to create graph 0: 6.135347127914429
# Time taken to calculate max flow boykov: 2.732808828353882
# Time taken to calculate max flow: 0.6649830341339111 flow: 260854
# Time taken to calculate max flow and min cut: 5.535606861114502
# edges that cross the partition: 2026743
# boundary vertices: 121045
# Time taken to calculate seam: 0.06522893905639648
# Time taken to convert boundary vertices to array: 0.4657020568847656
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.7395141124725342
# Time taken to add edges to graph: 1.3505957126617432
# Time taken to add source and sink nodes: 0.08536076545715332
# Time taken to create graph 2: 2.1881580352783203
# Time taken to calculate max flow boykov: 5.012484788894653
# Time taken to calculate max flow: 0.0428309440612793 flow: 20287
# Time taken to calculate max flow and min cut: 0.07280492782592773
# edges that cross the partition: 1090327
# boundary vertices: 7791
# Time taken to calculate seam: 0.0143280029296875
# Time taken to convert boundary vertices to array: 0.027889013290405273
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.39783334732055664
# Time taken to add edges to graph: 0.6475050449371338
# Time taken to add source and sink nodes: 0.3963799476623535
# Time taken to create graph 1: 1.4500229358673096
# Time taken to calculate max flow boykov: 0.22795486450195312
# Time taken to calculate max flow: 0.16504907608032227 flow: 70807
# Time taken to calculate max flow and min cut: 0.32084107398986816
# edges that cross the partition: 518947
# boundary vertices: 30802
# Time taken to calculate seam: 0.01652812957763672
# Time taken to convert boundary vertices to array: 0.1106879711151123
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.6107449531555176
# Time taken to add edges to graph: 2.631103038787842
# Time taken to add source and sink nodes: 2.0426321029663086
# Time taken to create graph 0: 6.316650867462158
# Time taken to calculate max flow boykov: 2.7485201358795166
# Time taken to calculate max flow: 0.6570208072662354 flow: 254590
# Time taken to calculate max flow and min cut: 5.012871026992798
# edges that cross the partition: 2071053
# boundary vertices: 122960
# Time taken to calculate seam: 0.05744314193725586
# Time taken to convert boundary vertices to array: 0.48136401176452637
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.7403881549835205
# Time taken to add edges to graph: 1.3686041831970215
# Time taken to add source and sink nodes: 0.0851430892944336
# Time taken to create graph 2: 2.208202838897705
# Time taken to calculate max flow boykov: 6.239145040512085
# Time taken to calculate max flow: 0.04246211051940918 flow: 20467
# Time taken to calculate max flow and min cut: 0.06565499305725098
# edges that cross the partition: 1089348
# boundary vertices: 7708
# Time taken to calculate seam: 0.015559196472167969
# Time taken to convert boundary vertices to array: 0.027769804000854492
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 1.0433659553527832
# Time taken to add edges to graph: 0.6231989860534668
# Time taken to add source and sink nodes: 0.3982999324798584
# Time taken to create graph 1: 2.073866844177246
# Time taken to calculate max flow boykov: 0.2200319766998291
# Time taken to calculate max flow: 0.16498208045959473 flow: 68548
# Time taken to calculate max flow and min cut: 0.33528923988342285
# edges that cross the partition: 500255
# boundary vertices: 30151
# Time taken to calculate seam: 0.015630006790161133
# Time taken to convert boundary vertices to array: 0.10551285743713379
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5591228008270264
# Time taken to add edges to graph: 2.519948720932007
# Time taken to add source and sink nodes: 2.004817008972168
# Time taken to create graph 0: 6.11624813079834
# Time taken to calculate max flow boykov: 2.7191858291625977
# Time taken to calculate max flow: 0.6640818119049072 flow: 242782
# Time taken to calculate max flow and min cut: 5.170854806900024
# edges that cross the partition: 1990503
# boundary vertices: 120394
# Time taken to calculate seam: 0.05553293228149414
# Time taken to convert boundary vertices to array: 0.4661839008331299
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.7300519943237305
# Time taken to add edges to graph: 1.3418331146240234
# Time taken to add source and sink nodes: 0.08565211296081543
# Time taken to create graph 2: 2.1702120304107666
# Time taken to calculate max flow boykov: 5.2588629722595215
# Time taken to calculate max flow: 0.04239702224731445 flow: 20431
# Time taken to calculate max flow and min cut: 0.0738229751586914
# edges that cross the partition: 1085313
# boundary vertices: 7766
# Time taken to calculate seam: 0.01559591293334961
# Time taken to convert boundary vertices to array: 0.027444839477539062
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.39919471740722656
# Time taken to add edges to graph: 0.6384189128875732
# Time taken to add source and sink nodes: 0.3939030170440674
# Time taken to create graph 1: 1.439884901046753
# Time taken to calculate max flow boykov: 0.22335600852966309
# Time taken to calculate max flow: 0.16565203666687012 flow: 68269
# Time taken to calculate max flow and min cut: 0.31950807571411133
# edges that cross the partition: 515985
# boundary vertices: 30651
# Time taken to calculate seam: 0.016495227813720703
# Time taken to convert boundary vertices to array: 0.1091148853302002
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.6157879829406738
# Time taken to add edges to graph: 2.6046648025512695
# Time taken to add source and sink nodes: 1.9710941314697266
# Time taken to create graph 0: 6.224175930023193
# Time taken to calculate max flow boykov: 2.767733097076416
# Time taken to calculate max flow: 0.6583709716796875 flow: 243214
# Time taken to calculate max flow and min cut: 5.033689022064209
# edges that cross the partition: 2056639
# boundary vertices: 122729
# Time taken to calculate seam: 0.05703234672546387
# Time taken to convert boundary vertices to array: 0.47585582733154297
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.7259001731872559
# Time taken to add edges to graph: 1.325690746307373
# Time taken to add source and sink nodes: 0.08384227752685547
# Time taken to create graph 2: 2.148503065109253
# Time taken to calculate max flow boykov: 5.559467077255249
# Time taken to calculate max flow: 0.04331707954406738 flow: 20566
# Time taken to calculate max flow and min cut: 0.06592106819152832
# edges that cross the partition: 1078272
# boundary vertices: 7744
# Time taken to calculate seam: 0.015174150466918945
# Time taken to convert boundary vertices to array: 0.027498960494995117
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3947629928588867
# Time taken to add edges to graph: 0.6399281024932861
# Time taken to add source and sink nodes: 0.4024240970611572
# Time taken to create graph 1: 1.4459199905395508
# Time taken to calculate max flow boykov: 0.22055912017822266
# Time taken to calculate max flow: 0.1677870750427246 flow: 69556
# Time taken to calculate max flow and min cut: 0.32985782623291016
# edges that cross the partition: 510023
# boundary vertices: 30430
# Time taken to calculate seam: 0.01570606231689453
# Time taken to convert boundary vertices to array: 0.11096596717834473
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5714550018310547
# Time taken to add edges to graph: 2.578890085220337
# Time taken to add source and sink nodes: 2.0301969051361084
# Time taken to create graph 0: 6.2126829624176025
# Time taken to calculate max flow boykov: 2.7174160480499268
# Time taken to calculate max flow: 0.6640057563781738 flow: 246274
# Time taken to calculate max flow and min cut: 5.345434188842773
# edges that cross the partition: 2017724
# boundary vertices: 120891
# Time taken to calculate seam: 0.05610489845275879
# Time taken to convert boundary vertices to array: 0.4687919616699219
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.721750020980835
# Time taken to add edges to graph: 1.309471845626831
# Time taken to add source and sink nodes: 0.08376479148864746
# Time taken to create graph 2: 2.1280319690704346
# Time taken to calculate max flow boykov: 5.6646928787231445
# Time taken to calculate max flow: 0.04236006736755371 flow: 20728
# Time taken to calculate max flow and min cut: 0.07090091705322266
# edges that cross the partition: 1066132
# boundary vertices: 7687
# Time taken to calculate seam: 0.016126155853271484
# Time taken to convert boundary vertices to array: 0.027691125869750977
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.38937902450561523
# Time taken to add edges to graph: 0.6317648887634277
# Time taken to add source and sink nodes: 0.39756178855895996
# Time taken to create graph 1: 1.426927089691162
# Time taken to calculate max flow boykov: 0.22642016410827637
# Time taken to calculate max flow: 0.16611790657043457 flow: 71608
# Time taken to calculate max flow and min cut: 0.3346240520477295
# edges that cross the partition: 511263
# boundary vertices: 30105
# Time taken to calculate seam: 0.015957117080688477
# Time taken to convert boundary vertices to array: 0.10840988159179688
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 2.257032871246338
# Time taken to add edges to graph: 2.5934410095214844
# Time taken to add source and sink nodes: 1.9963879585266113
# Time taken to create graph 0: 6.879441976547241
# Time taken to calculate max flow boykov: 2.7449216842651367
# Time taken to calculate max flow: 0.6558079719543457 flow: 255328
# Time taken to calculate max flow and min cut: 5.220736980438232
# edges that cross the partition: 2037427
# boundary vertices: 120485
# Time taken to calculate seam: 0.055799007415771484
# Time taken to convert boundary vertices to array: 0.45278000831604004
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.7137830257415771
# Time taken to add edges to graph: 1.307870864868164
# Time taken to add source and sink nodes: 0.08478021621704102
# Time taken to create graph 2: 2.1198339462280273
# Time taken to calculate max flow boykov: 5.733577013015747
# Time taken to calculate max flow: 0.0434260368347168 flow: 20809
# Time taken to calculate max flow and min cut: 0.0753629207611084
# edges that cross the partition: 1065153
# boundary vertices: 7669
# Time taken to calculate seam: 0.01600503921508789
# Time taken to convert boundary vertices to array: 0.027739763259887695
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.401961088180542
# Time taken to add edges to graph: 0.6521728038787842
# Time taken to add source and sink nodes: 0.39681315422058105
# Time taken to create graph 1: 1.4604301452636719
# Time taken to calculate max flow boykov: 0.23085808753967285
# Time taken to calculate max flow: 0.16800904273986816 flow: 72688
# Time taken to calculate max flow and min cut: 0.3315408229827881
# edges that cross the partition: 516760
# boundary vertices: 30303
# Time taken to calculate seam: 0.0163118839263916
# Time taken to convert boundary vertices to array: 0.10895776748657227
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.6336400508880615
# Time taken to add edges to graph: 2.6415817737579346
# Time taken to add source and sink nodes: 2.0065152645111084
# Time taken to create graph 0: 6.31869101524353
# Time taken to calculate max flow boykov: 2.7531371116638184
# Time taken to calculate max flow: 0.6561899185180664 flow: 258181
# Time taken to calculate max flow and min cut: 5.168325185775757
# edges that cross the partition: 2058985
# boundary vertices: 121070
# Time taken to calculate seam: 0.05793905258178711
# Time taken to convert boundary vertices to array: 0.4829528331756592
# 64 64 64
# Time taken to add vertices to coord_to_vertex: 0.7197010517120361
# Time taken to add edges to graph: 1.3338799476623535
# Time taken to add source and sink nodes: 0.08251810073852539
# Time taken to create graph 2: 2.148078203201294
# Time taken to calculate max flow boykov: 6.7373340129852295
# Time taken to calculate max flow: 0.04214215278625488 flow: 20971
# Time taken to calculate max flow and min cut: 0.06369161605834961
# edges that cross the partition: 1061152
# boundary vertices: 7612
# Time taken to calculate seam: 0.01474308967590332
# Time taken to convert boundary vertices to array: 0.027683258056640625
# 128 128 128
# Time taken to add vertices to coord_to_vertex: 0.3828718662261963
# Time taken to add edges to graph: 0.6192672252655029
# Time taken to add source and sink nodes: 0.40614795684814453
# Time taken to create graph 1: 1.4169368743896484
# Time taken to calculate max flow boykov: 0.2174849510192871
# Time taken to calculate max flow: 0.163344144821167 flow: 71491
# Time taken to calculate max flow and min cut: 0.323498010635376
# edges that cross the partition: 496035
# boundary vertices: 29830
# Time taken to calculate seam: 0.014996051788330078
# Time taken to convert boundary vertices to array: 0.10620498657226562
# 256 256 256
# Time taken to add vertices to coord_to_vertex: 1.5155119895935059
# Time taken to add edges to graph: 2.474317789077759
# Time taken to add source and sink nodes: 2.065498113632202
# Time taken to create graph 0: 6.090242862701416
# Time taken to calculate max flow boykov: 2.7213761806488037
# Time taken to calculate max flow: 0.6541962623596191 flow: 254572
# Time taken to calculate max flow and min cut: 5.1954450607299805
# edges that cross the partition: 1969031
# boundary vertices: 118090
# Time taken to calculate seam: 0.053665876388549805
# Time taken to convert boundary vertices to array: 0.44834399223327637

# %%
print(mask_array_data[0].shape, raw_array_data.shape)
# Out:
# (256, 256, 256) (256, 256, 256)

# %%
#save results
# Create output directory if it doesn't exist
output_dir = os.path.join(os.getcwd(), 'output/densified_cubes')
os.makedirs(output_dir, exist_ok=True)

# Save mask_array_data[0] as NRRD with a timestamp
mask_nrrd_path = os.path.join(output_dir, f'densified_label_{timestamp}.nrrd')
nrrd.write(mask_nrrd_path, mask_array_data[0])
print(f"Saved mask_array_data[0] to {mask_nrrd_path}")

# Save raw_array_data as NRRD with a timestamp
raw_nrrd_path = os.path.join(output_dir, f'densified_data_{timestamp}.nrrd')
nrrd.write(raw_nrrd_path, raw_array_data)
print(f"Saved raw_array_data to {raw_nrrd_path}")
# Out:
# Saved mask_array_data[0] to /Users/jamesdarby/Documents/VesuviusScroll/GP/3D_sheet_carving/output/densified_cubes/densified_label_20240606_214137.nrrd
# Saved raw_array_data to /Users/jamesdarby/Documents/VesuviusScroll/GP/3D_sheet_carving/output/densified_cubes/densified_data_20240606_214137.nrrd

# %%
#plot seam ontop of mask array
res_i = 0
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(mark_boundaries_color(raw_array_data[:,slice_index,:], mask_array_data[res_i][:,slice_index,:]))
    elif axis == 2:
        plt.imshow(mark_boundaries_color(raw_array_data[:,:,slice_index], mask_array_data[res_i][:,:,slice_index]))
    else:
        plt.imshow(mark_boundaries_color(raw_array_data[slice_index,:,:], mask_array_data[res_i][slice_index,:,:]))
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=boundary_array.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
#plot boundary array, aka seam to remove
res_i = 0
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(boundary_array[:,slice_index,:])
    elif axis == 2:
        plt.imshow(boundary_array[:,:,slice_index])
    else:
        plt.imshow(boundary_array[slice_index,:,:])
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=boundary_array.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>

# %%
#plot seam ontop of mask array
res_i = 0
def plot_slice(slice_index, axis=0):
    plt.figure(figsize=(8, 6))
    if axis == 1:
        plt.imshow(mark_boundaries_color(boundary_array[:,slice_index,:], reduced_mask_data[res_i][:,slice_index,:]))
    elif axis == 2:
        plt.imshow(mark_boundaries_color(boundary_array[:,:,slice_index], reduced_mask_data[res_i][:,:,slice_index]))
    else:
        plt.imshow(mark_boundaries_color(boundary_array[slice_index,:,:], reduced_mask_data[res_i][slice_index,:,:]))
    plt.colorbar()
    plt.title(f'Slice {slice_index}')
    plt.show()

# Create a slider to browse through slices
interact(plot_slice, slice_index=IntSlider(min=0, max=boundary_array.shape[0]-1, step=1, value=0), axis=IntSlider(min=0, max=2, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='slice_index', max=255), IntSlider(value=0, description='…
# <function __main__.plot_slice(slice_index, axis=0)>
